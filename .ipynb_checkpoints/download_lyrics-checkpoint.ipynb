# %%
import lyricsgenius as genius
import pandas as pd
import re

# %%
## Artists

# %%
noms = pd.read_csv('data/billboard_nominees.csv')
wins = noms.groupby('Artist')['Winner'].agg('sum').rename('wins')
nominations = noms.groupby('Artist')['Winner'].agg('count').rename('nominations')

# %%
bb_artists = pd.DataFrame([wins, nominations]).T
bb_artists
# Out:
#                          wins  nominations
# Artist
# 50 Cent                     2            2
# Bow Wow                     0            1
# Busta Rhymes                0            2
# Cardi B                     0            1
# Chingy                      0            1
# City High                   0            1
# DaBaby                      0            2
# Desiigner                   0            1
# Drake                       3           10
# Eminem                      2            2
# Fabolous                    0            1
# Fat Joe                     0            1
# Fetty Wap                   0            1
# Flo Rida                    0            1
# Future                      0            2
# Iggy Azalea                 1            1
# J. Cole                     0            2
# JT Money                    0            1
# Ja Rule                     0            1
# Jay-Z                       1            3
# Juice Wrld                  0            3
# Kanye West                  1            1
# Kendrick Lamar              1            1
# LMFAO                       0            1
# Lil Baby                    0            1
# Lil Nas X                   0            1
# Lil Romeo                   1            1
# Lil Uzi Vert                0            1
# Lil Wayne                   1            2
# Ludacris                    0            4
# MC Lyte                     0            1
# Macklemore & Ryan Lewis     0            1
# Mase                        1            2
# Migos                       0            1
# Nelly                       1            1
# Nicki Minaj                 1            4
# Outkast                     0            1
# P Diddy                     1            2
# Pitbull                     0            2
# Pop Smoke                   1            1
# Post Malone                 1            3
# Psy                         0            1
# Rae Sremmurd                0            2
# Roddy Ricch                 0            1
# Sean Paul                   0            2
# Silentó                     0            1
# Solé                        0            1
# T.I.                        1            2
# The Game                    0            1
# The Notorious B.I.G.        0            1
# Travis Scott                0            1
# Twista                      0            1
# Wiz Khalifa                 0            2
# Wyclef Jean                 0            1
# Yung Joc                    0            1

# %% [markdown]
# ## Genius API

# %%
api=genius.Genius('wKbk7ZVUTanJoxvF2sIpnkw2c9paQ7-bD7dXZ85SJ3L3Jp8SYwkMmA3NcnXKOjdz',
                  skip_non_songs=True,
                  excluded_terms=["(Remix), (Solo), (Live)"],
                  remove_section_headers=True)
api.timeout=15
api.retries=3

# %%
def getSongs(artist, k):
    songs = api.search_artist(artist, max_songs=k, sort='popularity').songs
    return (artist, songs)

# %%
artists_songs = [getSongs(artist, 50) for artist in bb_artists.index]
# Out:
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "Patiently Waiting"
# Song 5: "P.I.M.P."
# Song 6: "My Life"
# Song 7: "Candy Shop"
# Song 8: "I’m the Man"
# Song 9: "We Up"
# Song 10: "Best Friend"
# Song 11: "Wanksta"
# Song 12: "Ghetto Qu’ran (Forgive Me)"
# Song 13: "Hustler’s Ambition"
# Song 14: "Big Rich Town"
# Song 15: "Window Shopper"
# Song 16: "I’m the Man (Remix)"
# Song 17: "Heat"
# Song 18: "If I Can’t"
# Song 19: "Back Down"
# Song 20: "What Up Gangsta"
# Song 21: "Just a Lil’ Bit"
# Song 22: "How to Rob"
# Song 23: "Life’s on the Line"
# Song 24: "Don’t Push Me"
# Song 25: "High All the Time"
# Song 26: "When it Rains it Pours"
# Song 27: "No Romeo No Juliet"
# Song 28: "Ayo Technology"
# Song 29: "U Not Like Me"
# Song 30: "I’ll Whip Ya Head Boy"
# Song 31: "I Get Money"
# Song 32: "Major Distribution"
# Song 33: "Piggy Bank"
# Song 34: "Too Rich for the Bitch"
# Song 35: "Tryna Fuck Me Over"
# Song 36: "P.I.M.P (G-Unit Remix)"
# Song 37: "Outta Control (Remix)"
# Song 38: "Places to Go"
# Song 39: "9 Shots"
# Song 40: "I’m Supposed to Die Tonight"
# Song 41: "Hate It or Love It (G-Unit Remix)"
# Song 42: "Straight to the Bank"
# Song 43: "Disco Inferno"
# Song 44: "New Day"
# Song 45: "GATman and Robbin"
# Song 46: "A Baltimore Love Thing"
# Song 47: "Still Think I’m Nothing"
# Song 48: "I’ll Still Kill"
# Song 49: "Click Clack Pow Officer Down"
# Song 50: "Best Friend (Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Bow Wow...
#
# Song 1: "Like You"
# Song 2: "Let Me Hold You"
# Song 3: "Shortie Like Mine"
# Song 4: "Ain’t Thinkin’ ’Bout You"
# Song 5: "Outta My System"
# Song 6: "Basketball"
# Song 7: "Bow Wow (That’s My Name)"
# Song 8: "Pussy On My Mind"
# Song 9: "Fresh Azimiz"
# Song 10: "Better"
# Song 11: "Sweat"
# Song 12: "Dope (Freestyle)"
# Song 13: "Like You [video version]"
# Song 14: "Marco Polo"
# Song 15: "We In Da Club"
# Song 16: "Bounce With Me"
# Song 17: "Bow Wow (That’s My Name) (Remix)"
# Song 18: "Take Ya Home"
# Song 19: "Yeaahh"
# Song 20: "You Can Get It All"
# Song 21: "Boy or Girl"
# Song 22: "My Baby"
# Song 23: "We ’Bout That (Eat the Cake)"
# Song 24: "Let’s Get Down"
# Song 25: "Pussy On My Mind (Remix)"
# Song 26: "K-I-S-S My A-S-S"
# Song 27: "I’m a Flirt"
# Song 28: "Like You (A Cappella)"
# Song 29: "Sell My Soul"
# Song 30: "Thank You"
# Song 31: "Big Dreams"
# Song 32: "BET Rapcity Freestyle"
# Song 33: "Cuff Yo Chick"
# Song 34: "Break It Down"
# Song 35: "4 Corners"
# Song 36: "Pole In My Basement"
# Song 37: "What’s my name"
# Song 38: "Drunk Off Ciroc"
# Song 39: "Playin’ the Game"
# Song 40: "Too Real"
# Song 41: "To My Mama"
# Song 42: "Fresh Azimiz (Remix)"
# Song 43: "Put That On My Hood"
# Song 44: "Puppy Love"
# Song 45: "Nightmares Of The Bottom Freestyle"
# Song 46: "Like Mike"
# Song 47: "Drank In My Cup Freestyle"
# Song 48: "My Pain"
# Song 49: "Ghetto Girls"
# Song 50: "Crunch Time"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Busta Rhymes...
#
# Song 1: "Calm Down"
# Song 2: "#TwerkIt"
# Song 3: "#TwerkIt (Solo)"
# Song 4: "Thank You"
# Song 5: "Break Ya Neck"
# Song 6: "I’ll Hurt You"
# Song 7: "Look Over Your Shoulder"
# Song 8: "Can You Keep Up?"
# Song 9: "I Know What You Want"
# Song 10: "Touch It (Official Remix)"
# Song 11: "Touch It"
# Song 12: "Put Your Hands Where My Eyes Could See"
# Song 13: "Why Stop Now"
# Song 14: "Arab Money"
# Song 15: "Gimme Some More"
# Song 16: "Arab Money (Remix)"
# Song 17: "Pass the Courvoisier Part II"
# Song 18: "Woo Hah!! Got You All in Check"
# Song 19: "Hello"
# Song 20: "Dangerous"
# Song 21: "Girlfriend"
# Song 22: "Why Stop Now (Remix)"
# Song 23: "We Made It"
# Song 24: "Holla"
# Song 25: "Touch It (Remix 2.0)"
# Song 26: "Flipmode Squad Meets Def Squad"
# Song 27: "What’s It Gonna Be?!"
# Song 28: "Everything Remains Raw"
# Song 29: "Respect My Conglomerate"
# Song 30: "Woo-Hah!! Got You All in Check (Remix)"
# Song 31: "In The Ghetto"
# Song 32: "Poetic Justice"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5180/701507322.py in <module>
# ----> 1 artists_songs = [getSongs(artist, 50) for artist in bb_artists.index]
#
# ~\AppData\Local\Temp/ipykernel_5180/701507322.py in <listcomp>(.0)
# ----> 1 artists_songs = [getSongs(artist, 50) for artist in bb_artists.index]
#
# ~\AppData\Local\Temp/ipykernel_5180/2753783233.py in getSongs(artist, k)
#       1 def getSongs(artist, k):
# ----> 2     songs = api.search_artist(artist, max_songs=k, sort='popularity').songs
#       3     return (artist, songs)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\genius.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id, include_features)
#     566                     lyrics = ""
#     567                 if get_full_info:
# --> 568                     new_info = self.song(song_info['id'])['song']
#     569                     song_info.update(new_info)
#     570                 song = Song(self, song_info, lyrics)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\api\api.py in song(self, song_id, text_format)
#     435         endpoint = "songs/{id}".format(id=song_id)
#     436         params = {'text_format': text_format or self.response_format}
# --> 437         return self._make_request(endpoint, params_=params)
#     438
#     439     def web_page(self, raw_annotatable_url=None, canonical_url=None, og_url=None):
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\api\base.py in _make_request(self, path, method, params_, public_api, web, **kwargs)
#      89
#      90             # Enforce rate limiting
# ---> 91             time.sleep(self.sleep_time)
#      92
#      93         if web:
#
# KeyboardInterrupt:

# %%
from requests.exceptions import Timeout

def getSongs(artist, k):
    song_list = []
    retry=0
    while retry < 3:
        try:
            songs = api.search_artist(artist, max_songs=k, sort='popularity').songs
            song_list.append(songs)
        except Timeout:
            retry =+ 1
            continue
    return (artist, song_list)

# %%
artists_songs = [getSongs(artist, 50) for artist in bb_artists.index]
# Out:
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "Patiently Waiting"
# Song 5: "P.I.M.P."
# Song 6: "My Life"
# Song 7: "Candy Shop"
# Song 8: "I’m the Man"
# Song 9: "We Up"
# Song 10: "Best Friend"
# Song 11: "Wanksta"
# Song 12: "Ghetto Qu’ran (Forgive Me)"
# Song 13: "Hustler’s Ambition"
# Song 14: "Big Rich Town"
# Song 15: "Window Shopper"
# Song 16: "I’m the Man (Remix)"
# Song 17: "Heat"
# Song 18: "If I Can’t"
# Song 19: "Back Down"
# Song 20: "What Up Gangsta"
# Song 21: "Just a Lil’ Bit"
# Song 22: "How to Rob"
# Song 23: "Life’s on the Line"
# Song 24: "Don’t Push Me"
# Song 25: "High All the Time"
# Song 26: "When it Rains it Pours"
# Song 27: "No Romeo No Juliet"
# Song 28: "Ayo Technology"
# Song 29: "U Not Like Me"
# Song 30: "I’ll Whip Ya Head Boy"
# Song 31: "I Get Money"
# Song 32: "Major Distribution"
# Song 33: "Piggy Bank"
# Song 34: "Too Rich for the Bitch"
# Song 35: "Tryna Fuck Me Over"
# Song 36: "P.I.M.P (G-Unit Remix)"
# Song 37: "Outta Control (Remix)"
# Song 38: "Places to Go"
# Song 39: "9 Shots"
# Song 40: "I’m Supposed to Die Tonight"
# Song 41: "Hate It or Love It (G-Unit Remix)"
# Song 42: "Straight to the Bank"
# Song 43: "Disco Inferno"
# Song 44: "New Day"
# Song 45: "GATman and Robbin"
# Song 46: "A Baltimore Love Thing"
# Song 47: "Still Think I’m Nothing"
# Song 48: "I’ll Still Kill"
# Song 49: "Click Clack Pow Officer Down"
# Song 50: "Best Friend (Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "Patiently Waiting"
# Song 5: "P.I.M.P."
# Song 6: "My Life"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5180/4075352319.py in <module>
# ----> 1 artists_songs = [getSongs(artist, 50) for artist in bb_artists.index[:2]]
#
# ~\AppData\Local\Temp/ipykernel_5180/4075352319.py in <listcomp>(.0)
# ----> 1 artists_songs = [getSongs(artist, 50) for artist in bb_artists.index[:2]]
#
# ~\AppData\Local\Temp/ipykernel_5180/2041065274.py in getSongs(artist, k)
#       6     while retry < 3:
#       7         try:
# ----> 8             songs = api.search_artist(artist, max_songs=k, sort='popularity').songs
#       9             song_list.append(songs)
#      10         except Timeout:
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\genius.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id, include_features)
#     566                     lyrics = ""
#     567                 if get_full_info:
# --> 568                     new_info = self.song(song_info['id'])['song']
#     569                     song_info.update(new_info)
#     570                 song = Song(self, song_info, lyrics)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\api\api.py in song(self, song_id, text_format)
#     435         endpoint = "songs/{id}".format(id=song_id)
#     436         params = {'text_format': text_format or self.response_format}
# --> 437         return self._make_request(endpoint, params_=params)
#     438
#     439     def web_page(self, raw_annotatable_url=None, canonical_url=None, og_url=None):
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\lyricsgenius\api\base.py in _make_request(self, path, method, params_, public_api, web, **kwargs)
#      73             tries += 1
#      74             try:
# ---> 75                 response = self._session.request(method, uri,
#      76                                                  timeout=self.timeout,
#      77                                                  params=params_,
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\envs\pythonenv-nlp\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\anaconda3\envs\pythonenv-nlp\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\envs\pythonenv-nlp\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\envs\pythonenv-nlp\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\envs\pythonenv-nlp\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\envs\pythonenv-nlp\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import string

# %%
def downloadLyrics(artist, k, folder):
    print(f'Downloading the top {k} songs by {artist}.')
    
    # return top k songs by artist
    songs = api.search_artist(artist, max_songs=k, sort='popularity').songs
    
    # save each song's lyrics as a .txt file
    for song in songs:
        print(f'writing {artist}_{song.title}.txt')
        
        # remove tag at the end of all the lyrics
        lyrics = song.lyrics
        lyrics = re.sub(r"[0-9]*EmbedShare URLCopyEmbedCopy", "", lyrics)
        
        # save
        title = song.title.translate(str.maketrans('', '', string.punctuation))
        with open(f'{folder}/{artist}_{title}.txt', 'w', encoding="utf-8") as file:
            file.write(lyrics)
    
    print(f'Top {k} songs by {artist} downloaded.')
    
    return (artist, [song.title for song in songs])

# %%
songs[0].title.translate(str.maketrans('', '', string.punctuation))
# Out:
# 'Holy Grail'

# %%
"??dfddff^..??".translate(str.maketrans('', '', string.punctuation))
# Out:
# 'dfddff'

# %%
archive = [downloadLyrics(artist, 50, 'data') for artist in bb_artists.index]
# Out:
# Downloading the top 50 songs by 50 Cent.
# Searching for songs by 50 Cent...
#
# Song 1: "In da Club"
# Song 2: "21 Questions"
# Song 3: "Many Men (Wish Death)"
# Song 4: "Patiently Waiting"
# Song 5: "P.I.M.P."
# Song 6: "My Life"
# Song 7: "Candy Shop"
# Song 8: "I’m the Man"
# Song 9: "We Up"
# Song 10: "Best Friend"
# Song 11: "Wanksta"
# Song 12: "Ghetto Qu’ran (Forgive Me)"
# Song 13: "Hustler’s Ambition"
# Song 14: "Big Rich Town"
# Song 15: "Window Shopper"
# Song 16: "I’m the Man (Remix)"
# Song 17: "Heat"
# Song 18: "If I Can’t"
# Song 19: "Back Down"
# Song 20: "What Up Gangsta"
# Song 21: "Just a Lil’ Bit"
# Song 22: "How to Rob"
# Song 23: "Life’s on the Line"
# Song 24: "Don’t Push Me"
# Song 25: "High All the Time"
# Song 26: "When it Rains it Pours"
# Song 27: "No Romeo No Juliet"
# Song 28: "Ayo Technology"
# Song 29: "U Not Like Me"
# Song 30: "I’ll Whip Ya Head Boy"
# Song 31: "I Get Money"
# Song 32: "Major Distribution"
# Song 33: "Piggy Bank"
# Song 34: "Too Rich for the Bitch"
# Song 35: "Tryna Fuck Me Over"
# Song 36: "P.I.M.P (G-Unit Remix)"
# Song 37: "Outta Control (Remix)"
# Song 38: "Places to Go"
# Song 39: "9 Shots"
# Song 40: "I’m Supposed to Die Tonight"
# Song 41: "Hate It or Love It (G-Unit Remix)"
# Song 42: "Straight to the Bank"
# Song 43: "Disco Inferno"
# Song 44: "New Day"
# Song 45: "GATman and Robbin"
# Song 46: "A Baltimore Love Thing"
# Song 47: "Still Think I’m Nothing"
# Song 48: "I’ll Still Kill"
# Song 49: "Click Clack Pow Officer Down"
# Song 50: "Best Friend (Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing 50 Cent_In da Club.txt
# writing 50 Cent_21 Questions.txt
# writing 50 Cent_Many Men (Wish Death).txt
# writing 50 Cent_Patiently Waiting.txt
# writing 50 Cent_P.I.M.P..txt
# writing 50 Cent_My Life.txt
# writing 50 Cent_Candy Shop.txt
# writing 50 Cent_I’m the Man.txt
# writing 50 Cent_We Up.txt
# writing 50 Cent_Best Friend.txt
# writing 50 Cent_Wanksta.txt
# writing 50 Cent_Ghetto Qu’ran (Forgive Me).txt
# writing 50 Cent_Hustler’s Ambition.txt
# writing 50 Cent_Big Rich Town.txt
# writing 50 Cent_Window Shopper.txt
# writing 50 Cent_I’m the Man (Remix).txt
# writing 50 Cent_Heat.txt
# writing 50 Cent_If I Can’t.txt
# writing 50 Cent_Back Down.txt
# writing 50 Cent_What Up Gangsta.txt
# writing 50 Cent_Just a Lil’ Bit.txt
# writing 50 Cent_How to Rob.txt
# writing 50 Cent_Life’s on the Line.txt
# writing 50 Cent_Don’t Push Me.txt
# writing 50 Cent_High All the Time.txt
# writing 50 Cent_When it Rains it Pours.txt
# writing 50 Cent_No Romeo No Juliet.txt
# writing 50 Cent_Ayo Technology.txt
# writing 50 Cent_U Not Like Me.txt
# writing 50 Cent_I’ll Whip Ya Head Boy.txt
# writing 50 Cent_I Get Money.txt
# writing 50 Cent_Major Distribution.txt
# writing 50 Cent_Piggy Bank.txt
# writing 50 Cent_Too Rich for the Bitch.txt
# writing 50 Cent_Tryna Fuck Me Over.txt
# writing 50 Cent_P.I.M.P (G-Unit Remix).txt
# writing 50 Cent_Outta Control (Remix).txt
# writing 50 Cent_Places to Go.txt
# writing 50 Cent_9 Shots.txt
# writing 50 Cent_I’m Supposed to Die Tonight.txt
# writing 50 Cent_Hate It or Love It (G-Unit Remix).txt
# writing 50 Cent_Straight to the Bank.txt
# writing 50 Cent_Disco Inferno.txt
# writing 50 Cent_New Day.txt
# writing 50 Cent_GATman and Robbin.txt
# writing 50 Cent_A Baltimore Love Thing.txt
# writing 50 Cent_Still Think I’m Nothing.txt
# writing 50 Cent_I’ll Still Kill.txt
# writing 50 Cent_Click Clack Pow Officer Down.txt
# writing 50 Cent_Best Friend (Remix).txt
# Top 50 songs by 50 Cent downloaded.
# Downloading the top 50 songs by Bow Wow.
# Searching for songs by Bow Wow...
#
# Song 1: "Like You"
# Song 2: "Let Me Hold You"
# Song 3: "Shortie Like Mine"
# Song 4: "Ain’t Thinkin’ ’Bout You"
# Song 5: "Outta My System"
# Song 6: "Basketball"
# Song 7: "Bow Wow (That’s My Name)"
# Song 8: "Pussy On My Mind"
# Song 9: "Fresh Azimiz"
# Song 10: "Better"
# Song 11: "Sweat"
# Song 12: "Dope (Freestyle)"
# Song 13: "Like You [video version]"
# Song 14: "Marco Polo"
# Song 15: "We In Da Club"
# Song 16: "Bounce With Me"
# Song 17: "Bow Wow (That’s My Name) (Remix)"
# Song 18: "Take Ya Home"
# Song 19: "Yeaahh"
# Song 20: "You Can Get It All"
# Song 21: "Boy or Girl"
# Song 22: "My Baby"
# Song 23: "We ’Bout That (Eat the Cake)"
# Song 24: "Let’s Get Down"
# Song 25: "Pussy On My Mind (Remix)"
# Song 26: "K-I-S-S My A-S-S"
# Song 27: "I’m a Flirt"
# Song 28: "Like You (A Cappella)"
# Song 29: "Sell My Soul"
# Song 30: "Thank You"
# Song 31: "Big Dreams"
# Song 32: "BET Rapcity Freestyle"
# Song 33: "Cuff Yo Chick"
# Song 34: "Break It Down"
# Song 35: "4 Corners"
# Song 36: "Pole In My Basement"
# Song 37: "What’s my name"
# Song 38: "Drunk Off Ciroc"
# Song 39: "Playin’ the Game"
# Song 40: "Too Real"
# Song 41: "To My Mama"
# Song 42: "Fresh Azimiz (Remix)"
# Song 43: "Put That On My Hood"
# Song 44: "Puppy Love"
# Song 45: "Nightmares Of The Bottom Freestyle"
# Song 46: "Like Mike"
# Song 47: "Drank In My Cup Freestyle"
# Song 48: "My Pain"
# Song 49: "Ghetto Girls"
# Song 50: "Crunch Time"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Bow Wow_Like You.txt
# writing Bow Wow_Let Me Hold You.txt
# writing Bow Wow_Shortie Like Mine.txt
# writing Bow Wow_Ain’t Thinkin’ ’Bout You.txt
# writing Bow Wow_Outta My System.txt
# writing Bow Wow_Basketball.txt
# writing Bow Wow_Bow Wow (That’s My Name).txt
# writing Bow Wow_Pussy On My Mind.txt
# writing Bow Wow_Fresh Azimiz.txt
# writing Bow Wow_Better.txt
# writing Bow Wow_Sweat.txt
# writing Bow Wow_Dope (Freestyle).txt
# writing Bow Wow_Like You [video version].txt
# writing Bow Wow_Marco Polo.txt
# writing Bow Wow_We In Da Club.txt
# writing Bow Wow_Bounce With Me.txt
# writing Bow Wow_Bow Wow (That’s My Name) (Remix).txt
# writing Bow Wow_Take Ya Home.txt
# writing Bow Wow_Yeaahh.txt
# writing Bow Wow_You Can Get It All.txt
# writing Bow Wow_Boy or Girl.txt
# writing Bow Wow_My Baby.txt
# writing Bow Wow_We ’Bout That (Eat the Cake).txt
# writing Bow Wow_Let’s Get Down.txt
# writing Bow Wow_Pussy On My Mind (Remix).txt
# writing Bow Wow_K-I-S-S My A-S-S.txt
# writing Bow Wow_I’m a Flirt.txt
# writing Bow Wow_Like You (A Cappella).txt
# writing Bow Wow_Sell My Soul.txt
# writing Bow Wow_Thank You.txt
# writing Bow Wow_Big Dreams.txt
# writing Bow Wow_BET Rapcity Freestyle.txt
# writing Bow Wow_Cuff Yo Chick.txt
# writing Bow Wow_Break It Down.txt
# writing Bow Wow_4 Corners.txt
# writing Bow Wow_Pole In My Basement.txt
# writing Bow Wow_What’s my name.txt
# writing Bow Wow_Drunk Off Ciroc.txt
# writing Bow Wow_Playin’ the Game.txt
# writing Bow Wow_Too Real.txt
# writing Bow Wow_To My Mama.txt
# writing Bow Wow_Fresh Azimiz (Remix).txt
# writing Bow Wow_Put That On My Hood.txt
# writing Bow Wow_Puppy Love.txt
# writing Bow Wow_Nightmares Of The Bottom Freestyle.txt
# writing Bow Wow_Like Mike.txt
# writing Bow Wow_Drank In My Cup Freestyle.txt
# writing Bow Wow_My Pain.txt
# writing Bow Wow_Ghetto Girls.txt
# writing Bow Wow_Crunch Time.txt
# Top 50 songs by Bow Wow downloaded.
# Downloading the top 50 songs by Busta Rhymes.
# Searching for songs by Busta Rhymes...
#
# Song 1: "Calm Down"
# Song 2: "#TwerkIt"
# Song 3: "#TwerkIt (Solo)"
# Song 4: "Thank You"
# Song 5: "Break Ya Neck"
# Song 6: "I’ll Hurt You"
# Song 7: "Look Over Your Shoulder"
# Song 8: "Can You Keep Up?"
# Song 9: "I Know What You Want"
# Song 10: "Touch It (Official Remix)"
# Song 11: "Touch It"
# Song 12: "Put Your Hands Where My Eyes Could See"
# Song 13: "Why Stop Now"
# Song 14: "Arab Money"
# Song 15: "Gimme Some More"
# Song 16: "Arab Money (Remix)"
# Song 17: "Pass the Courvoisier Part II"
# Song 18: "Woo Hah!! Got You All in Check"
# Song 19: "Hello"
# Song 20: "Dangerous"
# Song 21: "Girlfriend"
# Song 22: "Why Stop Now (Remix)"
# Song 23: "We Made It"
# Song 24: "Holla"
# Song 25: "Touch It (Remix 2.0)"
# Song 26: "Flipmode Squad Meets Def Squad"
# Song 27: "What’s It Gonna Be?!"
# Song 28: "Everything Remains Raw"
# Song 29: "Respect My Conglomerate"
# Song 30: "Woo-Hah!! Got You All in Check (Remix)"
# Song 31: "In The Ghetto"
# Song 32: "Poetic Justice"
# Song 33: "Decision"
# Song 34: "Get It"
# Song 35: "Best I Ever Had (Remix)"
# Song 36: "Touch It (Remix Part 4) [Extended Video Remix]"
# Song 37: "I Love My Bitch"
# Song 38: "Pass the Courvoisier"
# Song 39: "Fastest rap ever (new 2011)"
# Song 40: "King Tut"
# Song 41: "E.L.E. 2 The Wrath of God"
# Song 42: "HAM Remix"
# Song 43: "Where I Belong"
# Song 44: "Satanic"
# Song 45: "Don’t Get Carried Away"
# Song 46: "Turn It Up (Remix)/Fire It Up"
# Song 47: "Light Your Ass on Fire"
# Song 48: "Ill Vibe"
# Song 49: "It’s a Party"
# Song 50: "The Ugliest"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Busta Rhymes_Calm Down.txt
# writing Busta Rhymes_#TwerkIt.txt
# writing Busta Rhymes_#TwerkIt (Solo).txt
# writing Busta Rhymes_Thank You.txt
# writing Busta Rhymes_Break Ya Neck.txt
# writing Busta Rhymes_I’ll Hurt You.txt
# writing Busta Rhymes_Look Over Your Shoulder.txt
# writing Busta Rhymes_Can You Keep Up?.txt
# writing Busta Rhymes_I Know What You Want.txt
# writing Busta Rhymes_Touch It (Official Remix).txt
# writing Busta Rhymes_Touch It.txt
# writing Busta Rhymes_Put Your Hands Where My Eyes Could See.txt
# writing Busta Rhymes_Why Stop Now.txt
# writing Busta Rhymes_Arab Money.txt
# writing Busta Rhymes_Gimme Some More.txt
# writing Busta Rhymes_Arab Money (Remix).txt
# writing Busta Rhymes_Pass the Courvoisier Part II.txt
# writing Busta Rhymes_Woo Hah!! Got You All in Check.txt
# writing Busta Rhymes_Hello.txt
# writing Busta Rhymes_Dangerous.txt
# writing Busta Rhymes_Girlfriend.txt
# writing Busta Rhymes_Why Stop Now (Remix).txt
# writing Busta Rhymes_We Made It.txt
# writing Busta Rhymes_Holla.txt
# writing Busta Rhymes_Touch It (Remix 2.0).txt
# writing Busta Rhymes_Flipmode Squad Meets Def Squad.txt
# writing Busta Rhymes_What’s It Gonna Be?!.txt
# writing Busta Rhymes_Everything Remains Raw.txt
# writing Busta Rhymes_Respect My Conglomerate.txt
# writing Busta Rhymes_Woo-Hah!! Got You All in Check (Remix).txt
# writing Busta Rhymes_In The Ghetto.txt
# writing Busta Rhymes_Poetic Justice.txt
# writing Busta Rhymes_Decision.txt
# writing Busta Rhymes_Get It.txt
# writing Busta Rhymes_Best I Ever Had (Remix).txt
# writing Busta Rhymes_Touch It (Remix Part 4) [Extended Video Remix].txt
# writing Busta Rhymes_I Love My Bitch.txt
# writing Busta Rhymes_Pass the Courvoisier.txt
# writing Busta Rhymes_Fastest rap ever (new 2011).txt
# writing Busta Rhymes_King Tut.txt
# writing Busta Rhymes_E.L.E. 2 The Wrath of God.txt
# writing Busta Rhymes_HAM Remix.txt
# writing Busta Rhymes_Where I Belong.txt
# writing Busta Rhymes_Satanic.txt
# writing Busta Rhymes_Don’t Get Carried Away.txt
# writing Busta Rhymes_Turn It Up (Remix)/Fire It Up.txt
# writing Busta Rhymes_Light Your Ass on Fire.txt
# writing Busta Rhymes_Ill Vibe.txt
# writing Busta Rhymes_It’s a Party.txt
# writing Busta Rhymes_The Ugliest.txt
# Top 50 songs by Busta Rhymes downloaded.
# Downloading the top 50 songs by Cardi B.
# Searching for songs by Cardi B...
#
# Song 1: "WAP"
# Song 2: "Bodak Yellow"
# Song 3: "Up"
# Song 4: "Bartier Cardi"
# Song 5: "Be Careful"
# Song 6: "Money"
# Song 7: "Press"
# Song 8: "I Do"
# Song 9: "Thru Your Phone"
# Song 10: "Drip"
# Song 11: "Ring"
# Song 12: "Get Up 10"
# Song 13: "Best Life"
# Song 14: "Bickenhead"
# Song 15: "WAP (Clean)"
# Song 16: "Money Bag"
# Song 17: "Red Barz"
# Song 18: "Foreva"
# Song 19: "Lick"
# Song 20: "Bodak Yellow (Latin Trap Remix)"
# Song 21: "Washpoppin"
# Song 22: "On Fleek"
# Song 23: "Selfish"
# Song 24: "Pull Up"
# Song 25: "Cheap Ass Weave"
# Song 26: "Lick (Remix)"
# Song 27: "Bodak Yellow (Remix)"
# Song 28: "Trust Issues"
# Song 29: "Sauce Boyz"
# Song 30: "Lit Thot"
# Song 31: "Back It Up"
# Song 32: "Hectic"
# Song 33: "Up (Radio Edit)"
# Song 34: "Stripper Hoe"
# Song 35: "Bronx Season"
# Song 36: "WAP (Demo)"
# Song 37: "Styling*"
# Song 38: "Leave That Bitch Alone"
# Song 39: "With That"
# Song 40: "B.O.N"
# Song 41: "Trick"
# Song 42: "I Like It (Kontra K & AK Ausserkontrolle Remix)"
# Song 43: "Booty*"
# Song 44: "What A Girl Likes"
# Song 45: "I Gotta Hurt You"
# Song 46: "Pop Off"
# Song 47: "How I Do"
# Song 48: "Rollin"
# Song 49: "Everything"
# Song 50: "Sick 16 (Freestyle)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Cardi B_WAP.txt
# writing Cardi B_Bodak Yellow.txt
# writing Cardi B_Up.txt
# writing Cardi B_Bartier Cardi.txt
# writing Cardi B_Be Careful.txt
# writing Cardi B_Money.txt
# writing Cardi B_Press.txt
# writing Cardi B_I Do.txt
# writing Cardi B_Thru Your Phone.txt
# writing Cardi B_Drip.txt
# writing Cardi B_Ring.txt
# writing Cardi B_Get Up 10.txt
# writing Cardi B_Best Life.txt
# writing Cardi B_Bickenhead.txt
# writing Cardi B_WAP (Clean).txt
# writing Cardi B_Money Bag.txt
# writing Cardi B_Red Barz.txt
# writing Cardi B_Foreva.txt
# writing Cardi B_Lick.txt
# writing Cardi B_Bodak Yellow (Latin Trap Remix).txt
# writing Cardi B_Washpoppin.txt
# writing Cardi B_On Fleek.txt
# writing Cardi B_Selfish.txt
# writing Cardi B_Pull Up.txt
# writing Cardi B_Cheap Ass Weave.txt
# writing Cardi B_Lick (Remix).txt
# writing Cardi B_Bodak Yellow (Remix).txt
# writing Cardi B_Trust Issues.txt
# writing Cardi B_Sauce Boyz.txt
# writing Cardi B_Lit Thot.txt
# writing Cardi B_Back It Up.txt
# writing Cardi B_Hectic.txt
# writing Cardi B_Up (Radio Edit).txt
# writing Cardi B_Stripper Hoe.txt
# writing Cardi B_Bronx Season.txt
# writing Cardi B_WAP (Demo).txt
# writing Cardi B_Styling*.txt
# writing Cardi B_Leave That Bitch Alone.txt
# writing Cardi B_With That.txt
# writing Cardi B_B.O.N.txt
# writing Cardi B_Trick.txt
# writing Cardi B_I Like It (Kontra K & AK Ausserkontrolle Remix).txt
# writing Cardi B_Booty*.txt
# writing Cardi B_What A Girl Likes.txt
# writing Cardi B_I Gotta Hurt You.txt
# writing Cardi B_Pop Off.txt
# writing Cardi B_How I Do.txt
# writing Cardi B_Rollin.txt
# writing Cardi B_Everything.txt
# writing Cardi B_Sick 16 (Freestyle).txt
# Top 50 songs by Cardi B downloaded.
# Downloading the top 50 songs by Chingy.
# Searching for songs by Chingy...
#
# Song 1: "Holidae In"
# Song 2: "Right Thurr"
# Song 3: "One Call Away"
# Song 4: "Pullin’ Me Back"
# Song 5: "Balla Baby"
# Song 6: "Right Thurr (Remix)"
# Song 7: "I Do"
# Song 8: "Dem Jeans"
# Song 9: "Chingy Jackpot"
# Song 10: "King Judah"
# Song 11: "Pulling Me Back"
# "Right Thurr (NBA Live Mix)" is not valid. Skipping.
# Song 12: "Don’t Worry"
# Song 13: "Sample Dat Ass"
# Song 14: "Balla Baby Remix"
# Song 15: "Fly Like Me"
# Song 16: "Check My Swag"
# Song 17: "Represent"
# Song 18: "26's (feat. Lil Wayne)"
# Song 19: "Brand New Kicks"
# Song 20: "Gettin’ It"
# Song 21: "Turn It Up"
# Song 22: "Bagg Up"
# Song 23: "Juice"
# Song 24: "Superhero"
# Song 25: "U a Freak (Nasty Girl)"
# Song 26: "Gimme Dat"
# "Jackpot The Pimp (Skit)" is not valid. Skipping.
# Song 27: "He’s Herre"
# Song 28: "Wurrs My Cash"
# Song 29: "Hate it or Love it"
# Song 30: "Make That Ass Talk (feat. Ziggy)"
# Song 31: "Let Me Luv U"
# "Professional*" is not valid. Skipping.
# Song 32: "Let’s Ride"
# Song 33: "Roll On ’Em"
# Song 34: "Leave Wit Me"
# Song 35: "Nike Aurr’s & Crispy Tee’s"
# Song 36: "Don’t Worry (feat. Janet Jackson)"
# Song 37: "Pullin’ Me Back (feat. Tyrese & Jermaine Dupri)"
# Song 38: "All the Way to St. Lou (feat. David Banner & Nate Dogg)"
# Song 39: "Fall-N (feat. G.I.B.)"
# Song 40: "Bounce That"
# Song 41: "Hands Up"
# Song 42: "Spend Some $"
# Song 43: "Club Gettin’ Crowded (feat. Three 6 Mafia)"
# Song 44: "We Got"
# Song 45: "Madd @ Me"
# Song 46: "How We Feel"
# Song 47: "All Aboard (Ride It)"
# "Fuck Dat Nigga (skit)" is not valid. Skipping.
# Song 48: "Don’t Really Care"
# Song 49: "Give Em Some Mo"
# Song 50: "Intro (Rid’in Wit Me)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Chingy_Holidae In.txt
# writing Chingy_Right Thurr.txt
# writing Chingy_One Call Away.txt
# writing Chingy_Pullin’ Me Back.txt
# writing Chingy_Balla Baby.txt
# writing Chingy_Right Thurr (Remix).txt
# writing Chingy_I Do.txt
# writing Chingy_Dem Jeans.txt
# writing Chingy_Chingy Jackpot.txt
# writing Chingy_King Judah.txt
# writing Chingy_Pulling Me Back.txt
# writing Chingy_Don’t Worry.txt
# writing Chingy_Sample Dat Ass.txt
# writing Chingy_Balla Baby Remix.txt
# writing Chingy_Fly Like Me.txt
# writing Chingy_Check My Swag.txt
# writing Chingy_Represent.txt
# writing Chingy_26's (feat. Lil Wayne).txt
# writing Chingy_Brand New Kicks.txt
# writing Chingy_Gettin’ It.txt
# writing Chingy_Turn It Up.txt
# writing Chingy_Bagg Up.txt
# writing Chingy_Juice.txt
# writing Chingy_Superhero.txt
# writing Chingy_U a Freak (Nasty Girl).txt
# writing Chingy_Gimme Dat.txt
# writing Chingy_He’s Herre.txt
# writing Chingy_Wurrs My Cash.txt
# writing Chingy_Hate it or Love it.txt
# writing Chingy_Make That Ass Talk (feat. Ziggy).txt
# writing Chingy_Let Me Luv U.txt
# writing Chingy_Let’s Ride.txt
# writing Chingy_Roll On ’Em.txt
# writing Chingy_Leave Wit Me.txt
# writing Chingy_Nike Aurr’s & Crispy Tee’s.txt
# writing Chingy_Don’t Worry (feat. Janet Jackson).txt
# writing Chingy_Pullin’ Me Back (feat. Tyrese & Jermaine Dupri).txt
# writing Chingy_All the Way to St. Lou (feat. David Banner & Nate Dogg).txt
# writing Chingy_Fall-N (feat. G.I.B.).txt
# writing Chingy_Bounce That.txt
# writing Chingy_Hands Up.txt
# writing Chingy_Spend Some $.txt
# writing Chingy_Club Gettin’ Crowded (feat. Three 6 Mafia).txt
# writing Chingy_We Got.txt
# writing Chingy_Madd @ Me.txt
# writing Chingy_How We Feel.txt
# writing Chingy_All Aboard (Ride It).txt
# writing Chingy_Don’t Really Care.txt
# writing Chingy_Give Em Some Mo.txt
# writing Chingy_Intro (Rid’in Wit Me).txt
# Top 50 songs by Chingy downloaded.
# Downloading the top 50 songs by City High.
# Searching for songs by City High...
#
# Song 1: "What Would You Do?"
# Song 2: "Caramel (Trackmasters Joint)"
# Song 3: "Caramel (Trackmasters Remix)"
# Song 4: "Caramel"
# Song 5: "So Many Things"
# Song 6: "15 Will Get You 20"
# Song 7: "The Only One I Trust"
# Song 8: "City High Anthem"
# Song 9: "You Don’t Know Me"
# Song 10: "Best Friends"
# Song 11: "Cats And Dogs"
# Song 12: "Sista"
# Song 13: "Song For You"
# Song 14: "Didn’t Ya"
# Song 15: "Three Way"
# Song 16: "Why"
# Song 17: "O Come All Ye Faithful"
# Done. Found 17 songs.
# writing City High_What Would You Do?.txt
# writing City High_Caramel (Trackmasters Joint).txt
# writing City High_Caramel (Trackmasters Remix).txt
# writing City High_Caramel.txt
# writing City High_So Many Things.txt
# writing City High_15 Will Get You 20.txt
# writing City High_The Only One I Trust.txt
# writing City High_City High Anthem.txt
# writing City High_You Don’t Know Me.txt
# writing City High_Best Friends.txt
# writing City High_Cats And Dogs.txt
# writing City High_Sista.txt
# writing City High_Song For You.txt
# writing City High_Didn’t Ya.txt
# writing City High_Three Way.txt
# writing City High_Why.txt
# writing City High_O Come All Ye Faithful.txt
# Top 50 songs by City High downloaded.
# Downloading the top 50 songs by DaBaby.
# Searching for songs by DaBaby...
#
# Song 1: "ROCKSTAR"
# Song 2: "Suge"
# Song 3: "BOP"
# Song 4: "INTRO"
# Song 5: "Goin Baby"
# Song 6: "VIBEZ"
# Song 7: "TOES"
# Song 8: "Next Song"
# Song 9: "Baby Sitter"
# Song 10: "Beatbox Freestyle"
# Song 11: "JUMP"
# Song 12: "ROCKSTAR (BLM Remix)"
# Song 13: "21"
# Song 14: "FIND MY WAY"
# Song 15: "Today (Intro)"
# Song 16: "Walker Texas Ranger"
# Song 17: "NASTY"
# Song 18: "OFF THE RIP"
# Song 19: "XXL"
# Song 20: "Blank Blank"
# Song 21: "BLAME IT ON BABY"
# Song 22: "Pull Up Music"
# Song 23: "SAD SHIT"
# Song 24: "POP STAR"
# Song 25: "GOSPEL"
# Song 26: "PRACTICE"
# Song 27: "4X"
# Song 28: "RAW SHIT"
# Song 29: "Pony"
# Song 30: "PICK UP"
# Song 31: "BLIND"
# Song 32: "LIGHTSKIN SHIT"
# Song 33: "Masterpiece"
# Song 34: "DaBaby Freestyle | LA Leakers Freestyle #076"
# Song 35: "Taking It Out"
# Song 36: "No Love"
# Song 37: "REALLY"
# Song 38: "Ball If I Want To"
# Song 39: "PEEP HOLE"
# Song 40: "NO DRIBBLE"
# Song 41: "Red Light Green Light"
# Song 42: "THERE HE GO"
# Song 43: "SHUT UP"
# Song 44: "PROLLY HEARD"
# Song 45: "CAN’T STOP"
# Song 46: "Gucci Peacoat"
# Song 47: "Carpet Burn"
# Song 48: "DROP"
# Song 49: "TALK ABOUT IT"
# Song 50: "Brother’s Keeper"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing DaBaby_ROCKSTAR.txt
# writing DaBaby_Suge.txt
# writing DaBaby_BOP.txt
# writing DaBaby_INTRO.txt
# writing DaBaby_Goin Baby.txt
# writing DaBaby_VIBEZ.txt
# writing DaBaby_TOES.txt
# writing DaBaby_Next Song.txt
# writing DaBaby_Baby Sitter.txt
# writing DaBaby_Beatbox Freestyle.txt
# writing DaBaby_JUMP.txt
# writing DaBaby_ROCKSTAR (BLM Remix).txt
# writing DaBaby_21.txt
# writing DaBaby_FIND MY WAY.txt
# writing DaBaby_Today (Intro).txt
# writing DaBaby_Walker Texas Ranger.txt
# writing DaBaby_NASTY.txt
# writing DaBaby_OFF THE RIP.txt
# writing DaBaby_XXL.txt
# writing DaBaby_Blank Blank.txt
# writing DaBaby_BLAME IT ON BABY.txt
# writing DaBaby_Pull Up Music.txt
# writing DaBaby_SAD SHIT.txt
# writing DaBaby_POP STAR.txt
# writing DaBaby_GOSPEL.txt
# writing DaBaby_PRACTICE.txt
# writing DaBaby_4X.txt
# writing DaBaby_RAW SHIT.txt
# writing DaBaby_Pony.txt
# writing DaBaby_PICK UP.txt
# writing DaBaby_BLIND.txt
# writing DaBaby_LIGHTSKIN SHIT.txt
# writing DaBaby_Masterpiece.txt
# writing DaBaby_DaBaby Freestyle | LA Leakers Freestyle #076.txt
# writing DaBaby_Taking It Out.txt
# writing DaBaby_No Love.txt
# writing DaBaby_REALLY.txt
# writing DaBaby_Ball If I Want To.txt
# writing DaBaby_PEEP HOLE.txt
# writing DaBaby_NO DRIBBLE.txt
# writing DaBaby_Red Light Green Light.txt
# writing DaBaby_THERE HE GO.txt
# writing DaBaby_SHUT UP.txt
# writing DaBaby_PROLLY HEARD.txt
# writing DaBaby_CAN’T STOP.txt
# writing DaBaby_Gucci Peacoat.txt
# writing DaBaby_Carpet Burn.txt
# writing DaBaby_DROP.txt
# writing DaBaby_TALK ABOUT IT.txt
# writing DaBaby_Brother’s Keeper.txt
# Top 50 songs by DaBaby downloaded.
# Downloading the top 50 songs by Desiigner.
# Searching for songs by Desiigner...
#
# Song 1: "Panda"
# Song 2: "Tiimmy Turner"
# Song 3: "Outlet"
# Song 4: "Zombie Walk"
# Song 5: "Tiimmy Turner (Remix)"
# Song 6: "XXL Freshman Freestyle: Desiigner"
# Song 7: "Overnight"
# Song 8: "Caliber"
# Song 9: "Up"
# Song 10: "Holy Ghost"
# Song 11: "Liife"
# Song 12: "Da Day"
# Song 13: "Make It Out"
# Song 14: "Monstas & Villains"
# Song 15: "Priice Tag"
# Song 16: "Jet"
# Song 17: "Roll Wit Me"
# Song 18: "Shooters"
# Song 19: "Talk Regardless"
# Song 20: "Thank God I Got It"
# Song 21: "Diva"
# Song 22: "Addams Family Freestyle"
# Song 23: "Overseas"
# Song 24: "Tonka"
# Song 25: "Malibu"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Desiigner-intro-lyrics
# Song 26: "Intro"
# Song 27: "Shoot"
# Song 28: "Destiination"
# "2016 MTV VMA White Carpet Interview/Freestyle" is not valid. Skipping.
# Song 29: "Hood"
# Song 30: "Formula"
# Song 31: "SOUL"
# Song 32: "AMEN"
# Song 33: "Pluto"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Desiigner-interlude-1-lyrics
# Song 34: "Interlude 1"
# Song 35: "Survivor"
# Song 36: "LA to NY"
# Song 37: "Tim Westwood Freestyle"
# Song 38: "I Get That"
# Song 39: "Pop iiT"
# Song 40: "After Party"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Desiigner-interlude-2-lyrics
# Song 41: "Interlude 2"
# Song 42: "This, That"
# Song 43: "Molly"
# Song 44: "Hate Me Now (FREESTYLE)"
# Song 45: "Liife (Remix)"
# Song 46: "Arms"
# Song 47: "Desiigner Freestyles on Flex | Freestyle #044"
# Song 48: "Friday The 13th"
# Song 49: "In My Ways"
# Song 50: "RIICH"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Desiigner_Panda.txt
# writing Desiigner_Tiimmy Turner.txt
# writing Desiigner_Outlet.txt
# writing Desiigner_Zombie Walk.txt
# writing Desiigner_Tiimmy Turner (Remix).txt
# writing Desiigner_XXL Freshman Freestyle: Desiigner.txt
# writing Desiigner_Overnight.txt
# writing Desiigner_Caliber.txt
# writing Desiigner_Up.txt
# writing Desiigner_Holy Ghost.txt
# writing Desiigner_Liife.txt
# writing Desiigner_Da Day.txt
# writing Desiigner_Make It Out.txt
# writing Desiigner_Monstas & Villains.txt
# writing Desiigner_Priice Tag.txt
# writing Desiigner_Jet.txt
# writing Desiigner_Roll Wit Me.txt
# writing Desiigner_Shooters.txt
# writing Desiigner_Talk Regardless.txt
# writing Desiigner_Thank God I Got It.txt
# writing Desiigner_Diva.txt
# writing Desiigner_Addams Family Freestyle.txt
# writing Desiigner_Overseas.txt
# writing Desiigner_Tonka.txt
# writing Desiigner_Malibu.txt
# writing Desiigner_Intro.txt
# writing Desiigner_Shoot.txt
# writing Desiigner_Destiination.txt
# writing Desiigner_Hood.txt
# writing Desiigner_Formula.txt
# writing Desiigner_SOUL.txt
# writing Desiigner_AMEN.txt
# writing Desiigner_Pluto.txt
# writing Desiigner_Interlude 1.txt
# writing Desiigner_Survivor.txt
# writing Desiigner_LA to NY.txt
# writing Desiigner_Tim Westwood Freestyle.txt
# writing Desiigner_I Get That.txt
# writing Desiigner_Pop iiT.txt
# writing Desiigner_After Party.txt
# writing Desiigner_Interlude 2.txt
# writing Desiigner_This, That.txt
# writing Desiigner_Molly.txt
# writing Desiigner_Hate Me Now (FREESTYLE).txt
# writing Desiigner_Liife (Remix).txt
# writing Desiigner_Arms.txt
# writing Desiigner_Desiigner Freestyles on Flex | Freestyle #044.txt
# writing Desiigner_Friday The 13th.txt
# writing Desiigner_In My Ways.txt
# writing Desiigner_RIICH.txt
# Top 50 songs by Desiigner downloaded.
# Downloading the top 50 songs by Drake.
# Searching for songs by Drake...
#
# Song 1: "God’s Plan"
# Song 2: "In My Feelings"
# Song 3: "Hotline Bling"
# Song 4: "One Dance"
# Song 5: "Hold On, We’re Going Home"
# Song 6: "Know Yourself"
# Song 7: "Back to Back"
# Song 8: "All Me"
# Song 9: "From Time"
# Song 10: "Fake Love"
# Song 11: "0 to 100 / The Catch Up"
# Song 12: "The Motto"
# Song 13: "Pound Cake / Paris Morton Music 2"
# Song 14: "Started from the Bottom"
# Song 15: "Marvin’s Room"
# Song 16: "HYFR (Hell Ya Fucking Right)"
# Song 17: "Passionfruit"
# Song 18: "Nice For What"
# Song 19: "Child’s Play"
# Song 20: "Energy"
# Song 21: "Too Good"
# Song 22: "Furthest Thing"
# Song 23: "Jungle"
# Song 24: "Over My Dead Body"
# Song 25: "Worst Behavior"
# Song 26: "Summer Sixteen"
# Song 27: "The Language"
# Song 28: "Girls Love Beyoncé"
# Song 29: "How Bout Now"
# Song 30: "Too Much"
# Song 31: "Shot for Me"
# Song 32: "Nonstop"
# Song 33: "Portland"
# Song 34: "Legend"
# Song 35: "Controlla"
# Song 36: "Gyalchester"
# Song 37: "U With Me?"
# Song 38: "Headlines"
# Song 39: "I’m Upset"
# Song 40: "Fire & Desire"
# Song 41: "Own It"
# Song 42: "Doing It Wrong"
# Song 43: "Crew Love"
# Song 44: "Do Not Disturb"
# Song 45: "Look What You’ve Done"
# Song 46: "Wu-Tang Forever"
# Song 47: "Teenage Fever"
# Song 48: "Take Care"
# Song 49: "The Motion"
# Song 50: "Free Smoke"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Drake_God’s Plan.txt
# writing Drake_In My Feelings.txt
# writing Drake_Hotline Bling.txt
# writing Drake_One Dance.txt
# writing Drake_Hold On, We’re Going Home.txt
# writing Drake_Know Yourself.txt
# writing Drake_Back to Back.txt
# writing Drake_All Me.txt
# writing Drake_From Time.txt
# writing Drake_Fake Love.txt
# writing Drake_0 to 100 / The Catch Up.txt
# writing Drake_The Motto.txt
# writing Drake_Pound Cake / Paris Morton Music 2.txt
# writing Drake_Started from the Bottom.txt
# writing Drake_Marvin’s Room.txt
# writing Drake_HYFR (Hell Ya Fucking Right).txt
# writing Drake_Passionfruit.txt
# writing Drake_Nice For What.txt
# writing Drake_Child’s Play.txt
# writing Drake_Energy.txt
# writing Drake_Too Good.txt
# writing Drake_Furthest Thing.txt
# writing Drake_Jungle.txt
# writing Drake_Over My Dead Body.txt
# writing Drake_Worst Behavior.txt
# writing Drake_Summer Sixteen.txt
# writing Drake_The Language.txt
# writing Drake_Girls Love Beyoncé.txt
# writing Drake_How Bout Now.txt
# writing Drake_Too Much.txt
# writing Drake_Shot for Me.txt
# writing Drake_Nonstop.txt
# writing Drake_Portland.txt
# writing Drake_Legend.txt
# writing Drake_Controlla.txt
# writing Drake_Gyalchester.txt
# writing Drake_U With Me?.txt
# writing Drake_Headlines.txt
# writing Drake_I’m Upset.txt
# writing Drake_Fire & Desire.txt
# writing Drake_Own It.txt
# writing Drake_Doing It Wrong.txt
# writing Drake_Crew Love.txt
# writing Drake_Do Not Disturb.txt
# writing Drake_Look What You’ve Done.txt
# writing Drake_Wu-Tang Forever.txt
# writing Drake_Teenage Fever.txt
# writing Drake_Take Care.txt
# writing Drake_The Motion.txt
# writing Drake_Free Smoke.txt
# Top 50 songs by Drake downloaded.
# Downloading the top 50 songs by Eminem.
# Searching for songs by Eminem...
#
# Song 1: "Rap God"
# Song 2: "Killshot"
# Song 3: "Godzilla"
# Song 4: "Lose Yourself"
# Song 5: "The Monster"
# Song 6: "Lucky You"
# Song 7: "The Ringer"
# Song 8: "Stan"
# Song 9: "River"
# Song 10: "Venom"
# Song 11: "Without Me"
# Song 12: "Berzerk"
# Song 13: "Not Alike"
# Song 14: "The Real Slim Shady"
# Song 15: "Fall"
# Song 16: "’Till I Collapse"
# Song 17: "Love the Way You Lie"
# Song 18: "8 Mile: B-Rabbit vs Papa Doc"
# Song 19: "Kamikaze"
# Song 20: "Walk on Water"
# Song 21: "Bad Guy"
# Song 22: "Mockingbird"
# Song 23: "Not Afraid"
# Song 24: "No Love"
# Song 25: "Beautiful"
# Song 26: "Headlights"
# Song 27: "Survival"
# Song 28: "Cleanin’ Out My Closet"
# Song 29: "Greatest"
# Song 30: "When I’m Gone"
# Song 31: "My Name Is"
# Song 32: "Superman"
# Song 33: "The Way I Am"
# Song 34: "Love Game"
# Song 35: "Unaccommodating"
# Song 36: "Space Bound"
# Song 37: "Legacy"
# Song 38: "Like Toy Soldiers"
# Song 39: "Sing for the Moment"
# Song 40: "Guts Over Fear"
# Song 41: "Gnat"
# Song 42: "Marshall Mathers"
# Song 43: "Kill You"
# Song 44: "Criminal"
# Song 45: "Believe"
# Song 46: "Stronger Than I Was"
# Song 47: "Evil Twin"
# Song 48: "Darkness"
# Song 49: "Detroit vs. Everybody"
# Song 50: "Kim"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Eminem_Rap God.txt
# writing Eminem_Killshot.txt
# writing Eminem_Godzilla.txt
# writing Eminem_Lose Yourself.txt
# writing Eminem_The Monster.txt
# writing Eminem_Lucky You.txt
# writing Eminem_The Ringer.txt
# writing Eminem_Stan.txt
# writing Eminem_River.txt
# writing Eminem_Venom.txt
# writing Eminem_Without Me.txt
# writing Eminem_Berzerk.txt
# writing Eminem_Not Alike.txt
# writing Eminem_The Real Slim Shady.txt
# writing Eminem_Fall.txt
# writing Eminem_’Till I Collapse.txt
# writing Eminem_Love the Way You Lie.txt
# writing Eminem_8 Mile: B-Rabbit vs Papa Doc.txt
# writing Eminem_Kamikaze.txt
# writing Eminem_Walk on Water.txt
# writing Eminem_Bad Guy.txt
# writing Eminem_Mockingbird.txt
# writing Eminem_Not Afraid.txt
# writing Eminem_No Love.txt
# writing Eminem_Beautiful.txt
# writing Eminem_Headlights.txt
# writing Eminem_Survival.txt
# writing Eminem_Cleanin’ Out My Closet.txt
# writing Eminem_Greatest.txt
# writing Eminem_When I’m Gone.txt
# writing Eminem_My Name Is.txt
# writing Eminem_Superman.txt
# writing Eminem_The Way I Am.txt
# writing Eminem_Love Game.txt
# writing Eminem_Unaccommodating.txt
# writing Eminem_Space Bound.txt
# writing Eminem_Legacy.txt
# writing Eminem_Like Toy Soldiers.txt
# writing Eminem_Sing for the Moment.txt
# writing Eminem_Guts Over Fear.txt
# writing Eminem_Gnat.txt
# writing Eminem_Marshall Mathers.txt
# writing Eminem_Kill You.txt
# writing Eminem_Criminal.txt
# writing Eminem_Believe.txt
# writing Eminem_Stronger Than I Was.txt
# writing Eminem_Evil Twin.txt
# writing Eminem_Darkness.txt
# writing Eminem_Detroit vs. Everybody.txt
# writing Eminem_Kim.txt
# Top 50 songs by Eminem downloaded.
# Downloading the top 50 songs by Fabolous.
# Searching for songs by Fabolous...
#
# Song 1: "Want You Back"
# Song 2: "Ready"
# Song 3: "Thim Slick"
# Song 4: "Into You (Remix)"
# Song 5: "Beauty"
# Song 6: "Doin It Well"
# Song 7: "Ball Drop"
# Song 8: "Cuffin Season"
# Song 9: "Young OG"
# Song 10: "Situationships"
# Song 11: "She Wildin’"
# Song 12: "Can’t Let You Go"
# Song 13: "Real One"
# Song 14: "Guess Who’s Bizzack?"
# Song 15: "Diced Pineapples"
# Song 16: "Gone for the Winter"
# Song 17: "Make Me Better"
# Song 18: "Diamonds (The Soul Tape 2)"
# Song 19: "The Plug"
# Song 20: "We Good"
# Song 21: "Faith in Me"
# Song 22: "Transformation"
# Song 23: "Goyard Bag"
# Song 24: "Louis Vuitton"
# Song 25: "Everything Was The Same"
# Song 26: "Pain"
# Song 27: "Got That Work"
# Song 28: "When I Feel Like It"
# Song 29: "Lituation"
# Song 30: "For the Love"
# Song 31: "We Get High"
# Song 32: "Lay Down"
# Song 33: "Breathe"
# Song 34: "The Get Back"
# Song 35: "Only Life I Know"
# Song 36: "You Be Killin Em"
# Song 37: "Time"
# Song 38: "Who Do You Love (Remix)"
# Song 39: "Cold Summer"
# Song 40: "Tell Ya Friends"
# Song 41: "Money Goes, Honey Stay (When the Money Goes Remix)"
# Song 42: "Sorry Not Sorry"
# Song 43: "To the Sky"
# Song 44: "Sacrifices"
# Song 45: "Throw It In The Bag (Remix)"
# Song 46: "For the Summer"
# Song 47: "You Made Me"
# Song 48: "Wolves In Sheeps Clothing"
# Song 49: "The Hope"
# Song 50: "Into You"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Fabolous_Want You Back.txt
# writing Fabolous_Ready.txt
# writing Fabolous_Thim Slick.txt
# writing Fabolous_Into You (Remix).txt
# writing Fabolous_Beauty.txt
# writing Fabolous_Doin It Well.txt
# writing Fabolous_Ball Drop.txt
# writing Fabolous_Cuffin Season.txt
# writing Fabolous_Young OG.txt
# writing Fabolous_Situationships.txt
# writing Fabolous_She Wildin’.txt
# writing Fabolous_Can’t Let You Go.txt
# writing Fabolous_Real One.txt
# writing Fabolous_Guess Who’s Bizzack?.txt
# writing Fabolous_Diced Pineapples.txt
# writing Fabolous_Gone for the Winter.txt
# writing Fabolous_Make Me Better.txt
# writing Fabolous_Diamonds (The Soul Tape 2).txt
# writing Fabolous_The Plug.txt
# writing Fabolous_We Good.txt
# writing Fabolous_Faith in Me.txt
# writing Fabolous_Transformation.txt
# writing Fabolous_Goyard Bag.txt
# writing Fabolous_Louis Vuitton.txt
# writing Fabolous_Everything Was The Same.txt
# writing Fabolous_Pain.txt
# writing Fabolous_Got That Work.txt
# writing Fabolous_When I Feel Like It.txt
# writing Fabolous_Lituation.txt
# writing Fabolous_For the Love.txt
# writing Fabolous_We Get High.txt
# writing Fabolous_Lay Down.txt
# writing Fabolous_Breathe.txt
# writing Fabolous_The Get Back.txt
# writing Fabolous_Only Life I Know.txt
# writing Fabolous_You Be Killin Em.txt
# writing Fabolous_Time.txt
# writing Fabolous_Who Do You Love (Remix).txt
# writing Fabolous_Cold Summer.txt
# writing Fabolous_Tell Ya Friends.txt
# writing Fabolous_Money Goes, Honey Stay (When the Money Goes Remix).txt
# writing Fabolous_Sorry Not Sorry.txt
# writing Fabolous_To the Sky.txt
# writing Fabolous_Sacrifices.txt
# writing Fabolous_Throw It In The Bag (Remix).txt
# writing Fabolous_For the Summer.txt
# writing Fabolous_You Made Me.txt
# writing Fabolous_Wolves In Sheeps Clothing.txt
# writing Fabolous_The Hope.txt
# writing Fabolous_Into You.txt
# Top 50 songs by Fabolous downloaded.
# Downloading the top 50 songs by Fat Joe.
# Searching for songs by Fat Joe...
#
# Song 1: "What’s Luv?"
# Song 2: "Yellow Tape"
# Song 3: "Make It Rain (Remix)"
# Song 4: "Another Round"
# Song 5: "So Excited"
# Song 6: "Lean Back (Remix)"
# Song 7: "Make It Rain"
# Song 8: "Pride N Joy"
# Song 9: "John Blaze"
# Song 10: "Fat Joe vs. George (Scary Movie 3 Rap Battle)"
# Song 11: "Another Round (Remix)"
# Song 12: "Ballin’"
# Song 13: "Firewater"
# Song 14: "Hold You Down"
# Song 15: "Love Me Long Time"
# Song 16: "All the Way Up [Official Remix]"
# Song 17: "My FoFo"
# Song 18: "Another Day"
# Song 19: "I Won’t Tell"
# Song 20: "Pick It Up"
# Song 21: "Bet Ya Man Can’t (Triz)"
# Song 22: "My Lifestyle"
# Song 23: "Instagram That Hoe"
# Song 24: "The Crackhouse"
# Song 25: "Flow Joe"
# Song 26: "Girl I’m A Bad Boy"
# Song 27: "Get It Poppin’"
# Song 28: "Fat Joe & Mysonne Freestyle on Flex | Freestyle #103"
# Song 29: "Watch Out"
# Song 30: "All I Need"
# Song 31: "The Crack Attack"
# Song 32: "Triplets"
# Song 33: "Porn Star"
# Song 34: "Love You To Pieces"
# Song 35: "Ain’t Sayin’ Nothing"
# Song 36: "Don Cartagena"
# Song 37: "Terror Squadians"
# Song 38: "The Fugitive"
# Song 39: "The Hidden Hand"
# Song 40: "Your Honor"
# Song 41: "Take a Look at My Life"
# Song 42: "My Lifestyle (Remix)"
# Song 43: "We Thuggin’"
# Song 44: "One"
# "1998" is not valid. Skipping.
# Song 45: "Aloha"
# Song 46: "Cupcake"
# Song 47: "The Shit is Real (DJ Premier Remix)"
# Song 48: "(Ha Ha) Slow Down"
# Song 49: "Success"
# Song 50: "Okay Okay"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Fat Joe_What’s Luv?.txt
# writing Fat Joe_Yellow Tape.txt
# writing Fat Joe_Make It Rain (Remix).txt
# writing Fat Joe_Another Round.txt
# writing Fat Joe_So Excited.txt
# writing Fat Joe_Lean Back (Remix).txt
# writing Fat Joe_Make It Rain.txt
# writing Fat Joe_Pride N Joy.txt
# writing Fat Joe_John Blaze.txt
# writing Fat Joe_Fat Joe vs. George (Scary Movie 3 Rap Battle).txt
# writing Fat Joe_Another Round (Remix).txt
# writing Fat Joe_Ballin’.txt
# writing Fat Joe_Firewater.txt
# writing Fat Joe_Hold You Down.txt
# writing Fat Joe_Love Me Long Time.txt
# writing Fat Joe_All the Way Up [Official Remix].txt
# writing Fat Joe_My FoFo.txt
# writing Fat Joe_Another Day.txt
# writing Fat Joe_I Won’t Tell.txt
# writing Fat Joe_Pick It Up.txt
# writing Fat Joe_Bet Ya Man Can’t (Triz).txt
# writing Fat Joe_My Lifestyle.txt
# writing Fat Joe_Instagram That Hoe.txt
# writing Fat Joe_The Crackhouse.txt
# writing Fat Joe_Flow Joe.txt
# writing Fat Joe_Girl I’m A Bad Boy.txt
# writing Fat Joe_Get It Poppin’.txt
# writing Fat Joe_Fat Joe & Mysonne Freestyle on Flex | Freestyle #103.txt
# writing Fat Joe_Watch Out.txt
# writing Fat Joe_All I Need.txt
# writing Fat Joe_The Crack Attack.txt
# writing Fat Joe_Triplets.txt
# writing Fat Joe_Porn Star.txt
# writing Fat Joe_Love You To Pieces.txt
# writing Fat Joe_Ain’t Sayin’ Nothing.txt
# writing Fat Joe_Don Cartagena.txt
# writing Fat Joe_Terror Squadians.txt
# writing Fat Joe_The Fugitive.txt
# writing Fat Joe_The Hidden Hand.txt
# writing Fat Joe_Your Honor.txt
# writing Fat Joe_Take a Look at My Life.txt
# writing Fat Joe_My Lifestyle (Remix).txt
# writing Fat Joe_We Thuggin’.txt
# writing Fat Joe_One.txt
# writing Fat Joe_Aloha.txt
# writing Fat Joe_Cupcake.txt
# writing Fat Joe_The Shit is Real (DJ Premier Remix).txt
# writing Fat Joe_(Ha Ha) Slow Down.txt
# writing Fat Joe_Success.txt
# writing Fat Joe_Okay Okay.txt
# Top 50 songs by Fat Joe downloaded.
# Downloading the top 50 songs by Fetty Wap.
# Searching for songs by Fetty Wap...
#
# Song 1: "Trap Queen"
# Song 2: "679"
# Song 3: "My Way (Remix)"
# Song 4: "My Way"
# Song 5: "Again"
# Song 6: "Jimmy Choo"
# Song 7: "RGF Island"
# Song 8: "Jugg"
# Song 9: "D.A.M (Dats All Me)"
# Song 10: "Wake Up"
# Song 11: "No Days Off"
# Song 12: "ZooWap"
# Song 13: "Trap Niggas Freestyle"
# Song 14: "Time"
# Song 15: "How We Do Things"
# Song 16: "1738"
# Song 17: "Couple Bands"
# Song 18: "Addicted"
# Song 19: "Trap Queen (Remix)"
# Song 20: "Like a Star"
# Song 21: "Cake Team"
# Song 22: "Westside"
# Song 23: "Ride Or Die"
# Song 24: "Make It"
# Song 25: "Decline (Remix)"
# Song 26: "Rewind"
# Song 27: "PARTY GIRL"
# Song 28: "Boomin"
# Song 29: "Zoovier"
# Song 30: "Love The Way"
# Song 31: "I’m Straight"
# Song 32: "I Wonder"
# Song 33: "Make You Feel Good"
# Song 34: "Know My Name"
# Song 35: "Trap Luv"
# Song 36: "Trap Queen (Gucci Mane & Quavo Remix)"
# Song 37: "Instagram"
# Song 38: "Rock My Chain"
# Song 39: "Different Now"
# Song 40: "Trap Queen (French Montana / Fabolous Remix)"
# Song 41: "Let It Bang"
# Song 42: "Throw It Back"
# Song 43: "Whateva"
# Song 44: "RGF Island (Remix)"
# Song 45: "Make You Smile"
# Song 46: "Strawberry Kush"
# Song 47: "Merry Xmas"
# Song 48: "Bahamas"
# Song 49: "Shorty"
# Song 50: "For My Team"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Fetty Wap_Trap Queen.txt
# writing Fetty Wap_679.txt
# writing Fetty Wap_My Way (Remix).txt
# writing Fetty Wap_My Way.txt
# writing Fetty Wap_Again.txt
# writing Fetty Wap_Jimmy Choo.txt
# writing Fetty Wap_RGF Island.txt
# writing Fetty Wap_Jugg.txt
# writing Fetty Wap_D.A.M (Dats All Me).txt
# writing Fetty Wap_Wake Up.txt
# writing Fetty Wap_No Days Off.txt
# writing Fetty Wap_ZooWap.txt
# writing Fetty Wap_Trap Niggas Freestyle.txt
# writing Fetty Wap_Time.txt
# writing Fetty Wap_How We Do Things.txt
# writing Fetty Wap_1738.txt
# writing Fetty Wap_Couple Bands.txt
# writing Fetty Wap_Addicted.txt
# writing Fetty Wap_Trap Queen (Remix).txt
# writing Fetty Wap_Like a Star.txt
# writing Fetty Wap_Cake Team.txt
# writing Fetty Wap_Westside.txt
# writing Fetty Wap_Ride Or Die.txt
# writing Fetty Wap_Make It.txt
# writing Fetty Wap_Decline (Remix).txt
# writing Fetty Wap_Rewind.txt
# writing Fetty Wap_PARTY GIRL.txt
# writing Fetty Wap_Boomin.txt
# writing Fetty Wap_Zoovier.txt
# writing Fetty Wap_Love The Way.txt
# writing Fetty Wap_I’m Straight.txt
# writing Fetty Wap_I Wonder.txt
# writing Fetty Wap_Make You Feel Good.txt
# writing Fetty Wap_Know My Name.txt
# writing Fetty Wap_Trap Luv.txt
# writing Fetty Wap_Trap Queen (Gucci Mane & Quavo Remix).txt
# writing Fetty Wap_Instagram.txt
# writing Fetty Wap_Rock My Chain.txt
# writing Fetty Wap_Different Now.txt
# writing Fetty Wap_Trap Queen (French Montana / Fabolous Remix).txt
# writing Fetty Wap_Let It Bang.txt
# writing Fetty Wap_Throw It Back.txt
# writing Fetty Wap_Whateva.txt
# writing Fetty Wap_RGF Island (Remix).txt
# writing Fetty Wap_Make You Smile.txt
# writing Fetty Wap_Strawberry Kush.txt
# writing Fetty Wap_Merry Xmas.txt
# writing Fetty Wap_Bahamas.txt
# writing Fetty Wap_Shorty.txt
# writing Fetty Wap_For My Team.txt
# Top 50 songs by Fetty Wap downloaded.
# Downloading the top 50 songs by Flo Rida.
# Searching for songs by Flo Rida...
#
# Song 1: "Low"
# Song 2: "Whistle"
# Song 3: "My House"
# Song 4: "GDFR"
# Song 5: "Right Round"
# Song 6: "Good Feeling"
# Song 7: "I Don’t Like It, I Love It"
# Song 8: "Wild Ones"
# Song 9: "I Cry"
# Song 10: "Hola"
# Song 11: "Can’t Believe It"
# Song 12: "Club Can’t Handle Me"
# Song 13: "Game Time"
# Song 14: "Sugar"
# Song 15: "Dancer"
# Song 16: "Low (Travis Barker Remix)"
# Song 17: "Hello Friday"
# Song 18: "Sweet Sensation"
# Song 19: "Elevator"
# Song 20: "Who Dat Girl"
# Song 21: "Zillionaire"
# Song 22: "R.O.O.T.S."
# Song 23: "Let It Roll, Pt. 2"
# Song 24: "In the Ayer"
# Song 25: "Be on You"
# Song 26: "How I Feel"
# Song 27: "Wobble"
# Song 28: "Tell Me When You Ready"
# Song 29: "Once In a Lifetime"
# Song 30: "Here It Is"
# Song 31: "Who’s With Me"
# Song 32: "Let It Roll"
# Song 33: "That’s What I Like"
# Song 34: "Turn Around (5, 4, 3, 2, 1)"
# Song 35: "Birthday"
# Song 36: "At Night"
# Song 37: "GDFR (Remix)"
# Song 38: "American Superstar"
# Song 39: "Turn Around (Part 2)"
# Song 40: "Run"
# Song 41: "Roll"
# Song 42: "Rear View"
# Song 43: "Low (Remix)"
# Song 44: "Available"
# Song 45: "In My Mind Part 3"
# Song 46: "We Already Won (Miami Heat)"
# Song 47: "Dirty Mind"
# Song 48: "Jump"
# Song 49: "Summer’s Not Ready"
# Song 50: "In My Mind Part 2"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Flo Rida_Low.txt
# writing Flo Rida_Whistle.txt
# writing Flo Rida_My House.txt
# writing Flo Rida_GDFR.txt
# writing Flo Rida_Right Round.txt
# writing Flo Rida_Good Feeling.txt
# writing Flo Rida_I Don’t Like It, I Love It.txt
# writing Flo Rida_Wild Ones.txt
# writing Flo Rida_I Cry.txt
# writing Flo Rida_Hola.txt
# writing Flo Rida_Can’t Believe It.txt
# writing Flo Rida_Club Can’t Handle Me.txt
# writing Flo Rida_Game Time.txt
# writing Flo Rida_Sugar.txt
# writing Flo Rida_Dancer.txt
# writing Flo Rida_Low (Travis Barker Remix).txt
# writing Flo Rida_Hello Friday.txt
# writing Flo Rida_Sweet Sensation.txt
# writing Flo Rida_Elevator.txt
# writing Flo Rida_Who Dat Girl.txt
# writing Flo Rida_Zillionaire.txt
# writing Flo Rida_R.O.O.T.S..txt
# writing Flo Rida_Let It Roll, Pt. 2.txt
# writing Flo Rida_In the Ayer.txt
# writing Flo Rida_Be on You.txt
# writing Flo Rida_How I Feel.txt
# writing Flo Rida_Wobble.txt
# writing Flo Rida_Tell Me When You Ready.txt
# writing Flo Rida_Once In a Lifetime.txt
# writing Flo Rida_Here It Is.txt
# writing Flo Rida_Who’s With Me.txt
# writing Flo Rida_Let It Roll.txt
# writing Flo Rida_That’s What I Like.txt
# writing Flo Rida_Turn Around (5, 4, 3, 2, 1).txt
# writing Flo Rida_Birthday.txt
# writing Flo Rida_At Night.txt
# writing Flo Rida_GDFR (Remix).txt
# writing Flo Rida_American Superstar.txt
# writing Flo Rida_Turn Around (Part 2).txt
# writing Flo Rida_Run.txt
# writing Flo Rida_Roll.txt
# writing Flo Rida_Rear View.txt
# writing Flo Rida_Low (Remix).txt
# writing Flo Rida_Available.txt
# writing Flo Rida_In My Mind Part 3.txt
# writing Flo Rida_We Already Won (Miami Heat).txt
# writing Flo Rida_Dirty Mind.txt
# writing Flo Rida_Jump.txt
# writing Flo Rida_Summer’s Not Ready.txt
# writing Flo Rida_In My Mind Part 2.txt
# Top 50 songs by Flo Rida downloaded.
# Downloading the top 50 songs by Future.
# Searching for songs by Future...
#
# Song 1: "Mask Off"
# Song 2: "Low Life"
# Song 3: "Life Is Good"
# Song 4: "March Madness"
# Song 5: "Where Ya At"
# Song 6: "Comin Out Strong"
# Song 7: "Fuck Up Some Commas"
# Song 8: "Codeine Crazy"
# Song 9: "Thought It Was a Drought"
# Song 10: "I Won"
# Song 11: "Used to This"
# Song 12: "Trap Niggas"
# Song 13: "Move That Dope"
# Song 14: "Stick Talk"
# Song 15: "Mask Off (Remix)"
# "Live from the Gutter" is not valid. Skipping.
# Song 16: "Throw Away"
# Song 17: "Jersey"
# Song 18: "Selfish"
# Song 19: "Purple Reign"
# Song 20: "Sh!t"
# Song 21: "Wicked"
# Song 22: "Honest"
# Song 23: "Turn On the Lights"
# Song 24: "56 Nights"
# Song 25: "Real Sisters"
# Song 26: "Draco"
# Song 27: "Perkys Calling"
# Song 28: "Karate Chop (Remix)"
# Song 29: "Rich $ex"
# Song 30: "The Percocet & Stripper Joint"
# Song 31: "Life Is Good (Remix)"
# Song 32: "Kno the Meaning"
# Song 33: "Blow a Bag"
# Song 34: "My Collection"
# Song 35: "Sorry"
# Song 36: "Lay Up"
# Song 37: "Karate Chop"
# Song 38: "You da Baddest"
# Song 39: "Never Gon Lose"
# Song 40: "Real and True"
# Song 41: "PIE"
# Song 42: "News or Something"
# Song 43: "Sh!t (Remix)"
# Song 44: "Incredible"
# Song 45: "Inside the Mattress"
# Song 46: "I’m So Groovy"
# Song 47: "Rent Money"
# Song 48: "My Savages"
# Song 49: "Solitaires"
# Song 50: "Never Stop"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Future_Mask Off.txt
# writing Future_Low Life.txt
# writing Future_Life Is Good.txt
# writing Future_March Madness.txt
# writing Future_Where Ya At.txt
# writing Future_Comin Out Strong.txt
# writing Future_Fuck Up Some Commas.txt
# writing Future_Codeine Crazy.txt
# writing Future_Thought It Was a Drought.txt
# writing Future_I Won.txt
# writing Future_Used to This.txt
# writing Future_Trap Niggas.txt
# writing Future_Move That Dope.txt
# writing Future_Stick Talk.txt
# writing Future_Mask Off (Remix).txt
# writing Future_Throw Away.txt
# writing Future_Jersey.txt
# writing Future_Selfish.txt
# writing Future_Purple Reign.txt
# writing Future_Sh!t.txt
# writing Future_Wicked.txt
# writing Future_Honest.txt
# writing Future_Turn On the Lights.txt
# writing Future_56 Nights.txt
# writing Future_Real Sisters.txt
# writing Future_Draco.txt
# writing Future_Perkys Calling.txt
# writing Future_Karate Chop (Remix).txt
# writing Future_Rich $ex.txt
# writing Future_The Percocet & Stripper Joint.txt
# writing Future_Life Is Good (Remix).txt
# writing Future_Kno the Meaning.txt
# writing Future_Blow a Bag.txt
# writing Future_My Collection.txt
# writing Future_Sorry.txt
# writing Future_Lay Up.txt
# writing Future_Karate Chop.txt
# writing Future_You da Baddest.txt
# writing Future_Never Gon Lose.txt
# writing Future_Real and True.txt
# writing Future_PIE.txt
# writing Future_News or Something.txt
# writing Future_Sh!t (Remix).txt
# writing Future_Incredible.txt
# writing Future_Inside the Mattress.txt
# writing Future_I’m So Groovy.txt
# writing Future_Rent Money.txt
# writing Future_My Savages.txt
# writing Future_Solitaires.txt
# writing Future_Never Stop.txt
# Top 50 songs by Future downloaded.
# Downloading the top 50 songs by Iggy Azalea.
# Searching for songs by Iggy Azalea...
#
# Song 1: "Work"
# Song 2: "Fancy"
# Song 3: "Kream"
# Song 4: "Black Widow"
# Song 5: "Sally Walker"
# Song 6: "Started"
# Song 7: "Change Your Life"
# Song 8: "D.R.U.G.S."
# Song 9: "Team"
# Song 10: "Pu$$y"
# Song 11: "Mo Bounce"
# Song 12: "Savior"
# Song 13: "Bounce"
# Song 14: "Murda Bizness"
# Song 15: "Leave It"
# Song 16: "New Bitch"
# Song 17: "Switch"
# Song 18: "Fuck Love"
# Song 19: "Rolex"
# Song 20: "Walk the Line"
# Song 21: "Don’t Need Y’all"
# "Cool For the Summer (Remix) (Live)" is not valid. Skipping.
# Song 22: "Fuck It Up"
# Song 23: "My World"
# Song 24: "Beg For It"
# Song 25: "Down South"
# Song 26: "Trouble"
# Song 27: "Lady Patra"
# Song 28: "Freestyle on Sway in the Morning"
# Song 29: "Iam The Stripclub"
# Song 30: "Goddess"
# Song 31: "Just Askin’"
# Song 32: "OMG"
# Song 33: "Survive the Summer"
# Song 34: "Just Wanna"
# Song 35: "100"
# Song 36: "Clap Back"
# Song 37: "Slo."
# Song 38: "Tokyo Snow Trip"
# Song 39: "Thanks I Get"
# Song 40: "Hello"
# Song 41: "Impossible Is Nothing"
# Song 42: "The Last Song"
# Song 43: "Hey Iggy"
# Song 44: "Kawasaki"
# Song 45: "Comme des Garçons"
# Song 46: "Azillion"
# Song 47: "Bac 2 Tha Future (My Time)"
# Song 48: "Boom Boom"
# Song 49: "Flexin & Finessin"
# Song 50: "Heavy Crown"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Iggy Azalea_Work.txt
# writing Iggy Azalea_Fancy.txt
# writing Iggy Azalea_Kream.txt
# writing Iggy Azalea_Black Widow.txt
# writing Iggy Azalea_Sally Walker.txt
# writing Iggy Azalea_Started.txt
# writing Iggy Azalea_Change Your Life.txt
# writing Iggy Azalea_D.R.U.G.S..txt
# writing Iggy Azalea_Team.txt
# writing Iggy Azalea_Pu$$y.txt
# writing Iggy Azalea_Mo Bounce.txt
# writing Iggy Azalea_Savior.txt
# writing Iggy Azalea_Bounce.txt
# writing Iggy Azalea_Murda Bizness.txt
# writing Iggy Azalea_Leave It.txt
# writing Iggy Azalea_New Bitch.txt
# writing Iggy Azalea_Switch.txt
# writing Iggy Azalea_Fuck Love.txt
# writing Iggy Azalea_Rolex.txt
# writing Iggy Azalea_Walk the Line.txt
# writing Iggy Azalea_Don’t Need Y’all.txt
# writing Iggy Azalea_Fuck It Up.txt
# writing Iggy Azalea_My World.txt
# ...
# Song 25: "SKELETONS"
# Song 26: "HOUSTONFORNICATION"
# Song 27: "​coordinate"
# Song 28: "R.I.P. SCREW"
# Song 29: "Skyfall"
# Song 30: "​wonderful"
# Song 31: "NC-17"
# Song 32: "Pornography"
# Song 33: "Pray 4 Love"
# Song 34: "​first take"
# Song 35: "​sweet sweet"
# Song 36: "5% TINT"
# Song 37: "COFFEE BEAN"
# Song 38: "WHO? WHAT!"
# Song 39: "Nightcrawler"
# Song 40: "Oh My Dis Side"
# Song 41: "Apple Pie"
# Song 42: "Don’t Play"
# Song 43: "Impossible"
# Song 44: "​lose"
# Song 45: "HIGHEST IN THE ROOM (REMIX)"
# Song 46: "​outside"
# Song 47: "Upper Echelon"
# Song 48: "Days Before Rodeo: The Prayer"
# Song 49: "RaRa"
# Song 50: "​guidance"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Travis Scott_SICKO MODE.txt
# writing Travis Scott_​goosebumps.txt
# writing Travis Scott_BUTTERFLY EFFECT.txt
# writing Travis Scott_HIGHEST IN THE ROOM.txt
# writing Travis Scott_Antidote.txt
# writing Travis Scott_​beibs in the trap.txt
# writing Travis Scott_STARGAZING.txt
# writing Travis Scott_YOSEMITE.txt
# writing Travis Scott_CAN’T SAY.txt
# writing Travis Scott_90210.txt
# writing Travis Scott_​through the late night.txt
# writing Travis Scott_STOP TRYING TO BE GOD.txt
# writing Travis Scott_Drugs You Should Try It.txt
# writing Travis Scott_NO BYSTANDERS.txt
# writing Travis Scott_Maria I’m Drunk.txt
# writing Travis Scott_3500.txt
# writing Travis Scott_WAKE UP.txt
# writing Travis Scott_​the ends.txt
# writing Travis Scott_CAROUSEL.txt
# writing Travis Scott_​way back.txt
# writing Travis Scott_FRANCHISE.txt
# writing Travis Scott_Watch.txt
# writing Travis Scott_ASTROTHUNDER.txt
# writing Travis Scott_Mamacita.txt
# writing Travis Scott_SKELETONS.txt
# writing Travis Scott_HOUSTONFORNICATION.txt
# writing Travis Scott_​coordinate.txt
# writing Travis Scott_R.I.P. SCREW.txt
# writing Travis Scott_Skyfall.txt
# writing Travis Scott_​wonderful.txt
# writing Travis Scott_NC-17.txt
# writing Travis Scott_Pornography.txt
# writing Travis Scott_Pray 4 Love.txt
# writing Travis Scott_​first take.txt
# writing Travis Scott_​sweet sweet.txt
# writing Travis Scott_5% TINT.txt
# writing Travis Scott_COFFEE BEAN.txt
# writing Travis Scott_WHO? WHAT!.txt
# writing Travis Scott_Nightcrawler.txt
# writing Travis Scott_Oh My Dis Side.txt
# writing Travis Scott_Apple Pie.txt
# writing Travis Scott_Don’t Play.txt
# writing Travis Scott_Impossible.txt
# writing Travis Scott_​lose.txt
# writing Travis Scott_HIGHEST IN THE ROOM (REMIX).txt
# writing Travis Scott_​outside.txt
# writing Travis Scott_Upper Echelon.txt
# writing Travis Scott_Days Before Rodeo: The Prayer.txt
# writing Travis Scott_RaRa.txt
# writing Travis Scott_​guidance.txt
# Top 50 songs by Travis Scott downloaded.
# Downloading the top 50 songs by Twista.
# Searching for songs by Twista...
#
# Song 1: "Slow Jamz"
# Song 2: "Overnight Celebrity"
# Song 3: "Wetter"
# Song 4: "Hope"
# Song 5: "Mista Tung Twista"
# Song 6: "Crisis"
# Song 7: "Look At Me Now (Remix)"
# Song 8: "Adrenaline Rush"
# Song 9: "Sunshine"
# Song 10: "Next to You"
# Song 11: "Hope Ft. Faith Evans"
# Song 12: "Do You"
# Song 13: "Make a Movie"
# Song 14: "3rd Eye"
# Song 15: "Gucci, Louis, Prada"
# Song 16: "Throwin My Money"
# Song 17: "Thinkin bout You (Remix)"
# Song 18: "Kill Us All"
# Song 19: "So Sexy"
# Song 20: "It’s Yours"
# Song 21: "Hope (Remix)"
# Song 22: "Emotions"
# Song 23: "Make a Movie (CB Version)"
# Song 24: "Get It Wet"
# Song 25: "Creep Fast"
# Song 26: "Runnin’ Off At Da Mouth"
# Song 27: "Birthday"
# Song 28: "It Feels So Good"
# Song 29: "Alright"
# Song 30: "Overdose"
# Song 31: "Girl Tonite"
# Song 32: "Ain’t No Hoes"
# Song 33: "Beast"
# Song 34: "Yellow Light"
# Song 35: "Fire"
# Song 36: "Death Before Dishonor"
# Song 37: "Models & Bottles"
# Song 38: "Badunkadunk"
# Song 39: "Ferocious"
# Song 40: "Dreams"
# Song 41: "Still Feels So Good"
# Song 42: "Like a 24"
# Song 43: "Legit Ballers"
# Song 44: "Yo Body"
# Song 45: "Get Me"
# Song 46: "Crook County (B.O.N.E. Crusher Mix)"
# Song 47: "Frum Da Tip of My Tongue"
# Song 48: "Misunderstood"
# Song 49: "Whitney Houston Tribute"
# Song 50: "Chocolate Fe’s and Redbones"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Twista_Slow Jamz.txt
# writing Twista_Overnight Celebrity.txt
# writing Twista_Wetter.txt
# writing Twista_Hope.txt
# writing Twista_Mista Tung Twista.txt
# writing Twista_Crisis.txt
# writing Twista_Look At Me Now (Remix).txt
# writing Twista_Adrenaline Rush.txt
# writing Twista_Sunshine.txt
# writing Twista_Next to You.txt
# writing Twista_Hope Ft. Faith Evans.txt
# writing Twista_Do You.txt
# writing Twista_Make a Movie.txt
# writing Twista_3rd Eye.txt
# writing Twista_Gucci, Louis, Prada.txt
# writing Twista_Throwin My Money.txt
# writing Twista_Thinkin bout You (Remix).txt
# writing Twista_Kill Us All.txt
# writing Twista_So Sexy.txt
# writing Twista_It’s Yours.txt
# writing Twista_Hope (Remix).txt
# writing Twista_Emotions.txt
# writing Twista_Make a Movie (CB Version).txt
# writing Twista_Get It Wet.txt
# writing Twista_Creep Fast.txt
# writing Twista_Runnin’ Off At Da Mouth.txt
# writing Twista_Birthday.txt
# writing Twista_It Feels So Good.txt
# writing Twista_Alright.txt
# writing Twista_Overdose.txt
# writing Twista_Girl Tonite.txt
# writing Twista_Ain’t No Hoes.txt
# writing Twista_Beast.txt
# writing Twista_Yellow Light.txt
# writing Twista_Fire.txt
# writing Twista_Death Before Dishonor.txt
# writing Twista_Models & Bottles.txt
# writing Twista_Badunkadunk.txt
# writing Twista_Ferocious.txt
# writing Twista_Dreams.txt
# writing Twista_Still Feels So Good.txt
# writing Twista_Like a 24.txt
# writing Twista_Legit Ballers.txt
# writing Twista_Yo Body.txt
# writing Twista_Get Me.txt
# writing Twista_Crook County (B.O.N.E. Crusher Mix).txt
# writing Twista_Frum Da Tip of My Tongue.txt
# writing Twista_Misunderstood.txt
# writing Twista_Whitney Houston Tribute.txt
# writing Twista_Chocolate Fe’s and Redbones.txt
# Top 50 songs by Twista downloaded.
# Downloading the top 50 songs by Wiz Khalifa.
# Searching for songs by Wiz Khalifa...
#
# Song 1: "See You Again"
# Song 2: "Remember You"
# Song 3: "We Dem Boyz"
# Song 4: "Black and Yellow"
# Song 5: "Medicated"
# Song 6: "Work Hard, Play Hard"
# Song 7: "Hopeless Romantic"
# Song 8: "Maan"
# Song 9: "Bake Sale"
# Song 10: "So High (Blacc Hollywood)"
# Song 11: "The Plan"
# Song 12: "Promises"
# Song 13: "Something New"
# Song 14: "The Thrill"
# Song 15: "Paperbond"
# Song 16: "King of Everything"
# Song 17: "Pull Up"
# Song 18: "KK"
# Song 19: "California"
# Song 20: "Roll Up"
# Song 21: "Taylor Gang"
# Song 22: "On My Level"
# Song 23: "Lit (Remix)"
# Song 24: "Started From The Bottom (Remix)"
# Song 25: "’Bout Me"
# Song 26: "Let It Go"
# Song 27: "Mezmorized"
# Song 28: "Black and Yellow (G-Mix)"
# Song 29: "GangBang"
# Song 30: "Up In It"
# Song 31: "When I’m Gone"
# Song 32: "The Race"
# Song 33: "It’s Nothin’"
# Song 34: "Ass Drop"
# Song 35: "My Favorite Song"
# Song 36: "Fr Fr"
# Song 37: "No Sleep"
# Song 38: "Look What I Got On"
# Song 39: "Mary 3x"
# Song 40: "Look Into My Eyes"
# Song 41: "Phone Numbers"
# Song 42: "Initiation"
# Song 43: "Say So"
# Song 44: "Still Blazin"
# Song 45: "MIA"
# Song 46: "Got Me Some More"
# Song 47: "Never Been"
# Song 48: "Reefer Party"
# Song 49: "Bluffin"
# Song 50: "Can’t Be Stopped"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Wiz Khalifa_See You Again.txt
# writing Wiz Khalifa_Remember You.txt
# writing Wiz Khalifa_We Dem Boyz.txt
# writing Wiz Khalifa_Black and Yellow.txt
# writing Wiz Khalifa_Medicated.txt
# writing Wiz Khalifa_Work Hard, Play Hard.txt
# writing Wiz Khalifa_Hopeless Romantic.txt
# writing Wiz Khalifa_Maan.txt
# writing Wiz Khalifa_Bake Sale.txt
# writing Wiz Khalifa_So High (Blacc Hollywood).txt
# writing Wiz Khalifa_The Plan.txt
# writing Wiz Khalifa_Promises.txt
# writing Wiz Khalifa_Something New.txt
# writing Wiz Khalifa_The Thrill.txt
# writing Wiz Khalifa_Paperbond.txt
# writing Wiz Khalifa_King of Everything.txt
# writing Wiz Khalifa_Pull Up.txt
# writing Wiz Khalifa_KK.txt
# writing Wiz Khalifa_California.txt
# writing Wiz Khalifa_Roll Up.txt
# writing Wiz Khalifa_Taylor Gang.txt
# writing Wiz Khalifa_On My Level.txt
# writing Wiz Khalifa_Lit (Remix).txt
# writing Wiz Khalifa_Started From The Bottom (Remix).txt
# writing Wiz Khalifa_’Bout Me.txt
# writing Wiz Khalifa_Let It Go.txt
# writing Wiz Khalifa_Mezmorized.txt
# writing Wiz Khalifa_Black and Yellow (G-Mix).txt
# writing Wiz Khalifa_GangBang.txt
# writing Wiz Khalifa_Up In It.txt
# writing Wiz Khalifa_When I’m Gone.txt
# writing Wiz Khalifa_The Race.txt
# writing Wiz Khalifa_It’s Nothin’.txt
# writing Wiz Khalifa_Ass Drop.txt
# writing Wiz Khalifa_My Favorite Song.txt
# writing Wiz Khalifa_Fr Fr.txt
# writing Wiz Khalifa_No Sleep.txt
# writing Wiz Khalifa_Look What I Got On.txt
# writing Wiz Khalifa_Mary 3x.txt
# writing Wiz Khalifa_Look Into My Eyes.txt
# writing Wiz Khalifa_Phone Numbers.txt
# writing Wiz Khalifa_Initiation.txt
# writing Wiz Khalifa_Say So.txt
# writing Wiz Khalifa_Still Blazin.txt
# writing Wiz Khalifa_MIA.txt
# writing Wiz Khalifa_Got Me Some More.txt
# writing Wiz Khalifa_Never Been.txt
# writing Wiz Khalifa_Reefer Party.txt
# writing Wiz Khalifa_Bluffin.txt
# writing Wiz Khalifa_Can’t Be Stopped.txt
# Top 50 songs by Wiz Khalifa downloaded.
# Downloading the top 50 songs by Wyclef Jean.
# Searching for songs by Wyclef Jean...
#
# Song 1: "Sweetest Girl (Dollar Bill)"
# Song 2: "911"
# Song 3: "Hendrix"
# Song 4: "Gone Till November"
# Song 5: "Perfect Gentleman"
# Song 6: "Diallo"
# "Chinese Restaurant Skit" is not valid. Skipping.
# "We Trying to Stay Alive" is not valid. Skipping.
# Song 7: "Two Wrongs"
# Song 8: "Guantanamera"
# Song 9: "If I Was President"
# Song 10: "Hip Hop"
# Song 11: "Another One Bites the Dust (Remix)"
# "Wild Thoughts (BBC 1 Radio Live Lounge)" is not valid. Skipping.
# Song 12: "I Swear"
# Song 13: "It Doesn’t Matter"
# Song 14: "Divine Sorrow"
# Song 15: "If I Was President (Dave Chappelle Version)"
# Song 16: "Million Voices"
# Song 17: "Thug Angels"
# Song 18: "Anything Can Happen"
# Song 19: "Sang Fezi"
# Song 20: "Borrowed Time"
# Song 21: "Gone Till November (The Makin’ Runs Remix)"
# Song 22: "Mona Lisa"
# Song 23: "Wish You Were Here"
# Song 24: "New Day"
# Song 25: "Apocalypse"
# Song 26: "Low Income"
# Song 27: "Open Letter (Freestyle)"
# Song 28: "Slow Down"
# Song 29: "Carry On"
# Song 30: "Dance Like This"
# Song 31: "Bubblegoose"
# Song 32: "Year of the Dragon"
# Song 33: "Party to Damascus"
# Song 34: "Hendrix (Spanglish Remix)"
# Song 35: "Fast Car (Remix)"
# Song 36: "What Happened to Love"
# Song 37: "I Don’t Wanna Lose Your Love"
# Song 38: "Jaspora"
# Song 39: "The Ring"
# Song 40: "Knockin’ on Heaven’s Door"
# Song 41: "Your Love (L.O.V.E. reggae mix) (feat. Eve)"
# Song 42: "Kenny Rogers - Pharoahe Monch Dub Plate"
# Song 43: "Gunpowder"
# Song 44: "Where Fugees At?"
# Song 45: "Demons Enjoy"
# Song 46: "Sweetest Girl (Remix)"
# Song 47: "Fast Car"
# Song 48: "Yelé"
# Song 49: "Lady Haiti"
# Song 50: "Whitney Houston Dub Plate"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Wyclef Jean_Sweetest Girl (Dollar Bill).txt
# writing Wyclef Jean_911.txt
# writing Wyclef Jean_Hendrix.txt
# writing Wyclef Jean_Gone Till November.txt
# writing Wyclef Jean_Perfect Gentleman.txt
# writing Wyclef Jean_Diallo.txt
# writing Wyclef Jean_Two Wrongs.txt
# writing Wyclef Jean_Guantanamera.txt
# writing Wyclef Jean_If I Was President.txt
# writing Wyclef Jean_Hip Hop.txt
# writing Wyclef Jean_Another One Bites the Dust (Remix).txt
# writing Wyclef Jean_I Swear.txt
# writing Wyclef Jean_It Doesn’t Matter.txt
# writing Wyclef Jean_Divine Sorrow.txt
# writing Wyclef Jean_If I Was President (Dave Chappelle Version).txt
# writing Wyclef Jean_Million Voices.txt
# writing Wyclef Jean_Thug Angels.txt
# writing Wyclef Jean_Anything Can Happen.txt
# writing Wyclef Jean_Sang Fezi.txt
# writing Wyclef Jean_Borrowed Time.txt
# writing Wyclef Jean_Gone Till November (The Makin’ Runs Remix).txt
# writing Wyclef Jean_Mona Lisa.txt
# writing Wyclef Jean_Wish You Were Here.txt
# writing Wyclef Jean_New Day.txt
# writing Wyclef Jean_Apocalypse.txt
# writing Wyclef Jean_Low Income.txt
# writing Wyclef Jean_Open Letter (Freestyle).txt
# writing Wyclef Jean_Slow Down.txt
# writing Wyclef Jean_Carry On.txt
# writing Wyclef Jean_Dance Like This.txt
# writing Wyclef Jean_Bubblegoose.txt
# writing Wyclef Jean_Year of the Dragon.txt
# writing Wyclef Jean_Party to Damascus.txt
# writing Wyclef Jean_Hendrix (Spanglish Remix).txt
# writing Wyclef Jean_Fast Car (Remix).txt
# writing Wyclef Jean_What Happened to Love.txt
# writing Wyclef Jean_I Don’t Wanna Lose Your Love.txt
# writing Wyclef Jean_Jaspora.txt
# writing Wyclef Jean_The Ring.txt
# writing Wyclef Jean_Knockin’ on Heaven’s Door.txt
# writing Wyclef Jean_Your Love (L.O.V.E. reggae mix) (feat. Eve).txt
# writing Wyclef Jean_Kenny Rogers - Pharoahe Monch Dub Plate.txt
# writing Wyclef Jean_Gunpowder.txt
# writing Wyclef Jean_Where Fugees At?.txt
# writing Wyclef Jean_Demons Enjoy.txt
# writing Wyclef Jean_Sweetest Girl (Remix).txt
# writing Wyclef Jean_Fast Car.txt
# writing Wyclef Jean_Yelé.txt
# writing Wyclef Jean_Lady Haiti.txt
# writing Wyclef Jean_Whitney Houston Dub Plate.txt
# Top 50 songs by Wyclef Jean downloaded.
# Downloading the top 50 songs by Yung Joc.
# Searching for songs by Yung Joc...
#
# Song 1: "It’s Goin’ Down"
# Song 2: "I Know You See It"
# Song 3: "Hear Me Coming"
# Song 4: "Coffee Shop"
# Song 5: "1st Time"
# Song 6: "A Couple Grand"
# "Get Me Bodied (Homecoming Live)" is not valid. Skipping.
# Song 7: "Dope Boy Magic"
# Song 8: "Drip"
# Song 9: "Knock It Out"
# Song 10: "I’m a G"
# Song 11: "Its Going Down"
# Song 12: "Drip (Remix)"
# Song 13: "Patron"
# Song 14: "Do Ya Bad"
# Song 15: "Cut Throat"
# Song 16: "Getting to Da Money"
# Song 17: "I Know You See It (Single Version)"
# Song 18: "Flip Flop"
# Song 19: "I Know What She Like"
# Song 20: "I got b**ches"
# Song 21: "’Bout It"
# Song 22: "Posted At The Store"
# Song 23: "Brand New"
# Song 24: "Bottle Poppin’"
# Song 25: "Don’t Play Wit It"
# Song 26: "New Joc City (Intro)"
# Song 27: "Boo Koo"
# Song 28: "Coffee Shop (Dirty Version)"
# Song 29: "Features"
# Song 30: "It’s Goin’ Down (Remix)"
# Song 31: "What She Like"
# Song 32: "Birds"
# Song 33: "So Good"
# Song 34: "1st Time (Remix)"
# Song 35: "It’s Goin’ Down - feat. Nitti Explicit"
# Song 36: "Buy U A Drank (Shawty Snappin’)"
# Song 37: "I’m Him"
# Song 38: "Picture Perfect"
# Song 39: "BYOB"
# Song 40: "Ugh"
# Song 41: "Hell Yeah"
# Song 42: "Play Your Cards"
# Song 43: "Might As Well"
# Song 44: "Chevy Smile"
# Song 45: "We bottle poppin"
# Song 46: "It’s Going Down Remix"
# Song 47: "Excuse Me Officer (Interlude)"
# Song 48: "500 Horses"
# Song 49: "Pak Man"
# Song 50: "Mollie"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# writing Yung Joc_It’s Goin’ Down.txt
# writing Yung Joc_I Know You See It.txt
# writing Yung Joc_Hear Me Coming.txt
# writing Yung Joc_Coffee Shop.txt
# writing Yung Joc_1st Time.txt
# writing Yung Joc_A Couple Grand.txt
# writing Yung Joc_Dope Boy Magic.txt
# writing Yung Joc_Drip.txt
# writing Yung Joc_Knock It Out.txt
# writing Yung Joc_I’m a G.txt
# writing Yung Joc_Its Going Down.txt
# writing Yung Joc_Drip (Remix).txt
# writing Yung Joc_Patron.txt
# writing Yung Joc_Do Ya Bad.txt
# writing Yung Joc_Cut Throat.txt
# writing Yung Joc_Getting to Da Money.txt
# writing Yung Joc_I Know You See It (Single Version).txt
# writing Yung Joc_Flip Flop.txt
# writing Yung Joc_I Know What She Like.txt
# writing Yung Joc_I got b**ches.txt
# writing Yung Joc_’Bout It.txt
# writing Yung Joc_Posted At The Store.txt
# writing Yung Joc_Brand New.txt
# writing Yung Joc_Bottle Poppin’.txt
# writing Yung Joc_Don’t Play Wit It.txt
# writing Yung Joc_New Joc City (Intro).txt
# writing Yung Joc_Boo Koo.txt
# writing Yung Joc_Coffee Shop (Dirty Version).txt
# writing Yung Joc_Features.txt
# writing Yung Joc_It’s Goin’ Down (Remix).txt
# writing Yung Joc_What She Like.txt
# writing Yung Joc_Birds.txt
# writing Yung Joc_So Good.txt
# writing Yung Joc_1st Time (Remix).txt
# writing Yung Joc_It’s Goin’ Down - feat. Nitti Explicit.txt
# writing Yung Joc_Buy U A Drank (Shawty Snappin’).txt
# writing Yung Joc_I’m Him.txt
# writing Yung Joc_Picture Perfect.txt
# writing Yung Joc_BYOB.txt
# writing Yung Joc_Ugh.txt
# writing Yung Joc_Hell Yeah.txt
# writing Yung Joc_Play Your Cards.txt
# writing Yung Joc_Might As Well.txt
# writing Yung Joc_Chevy Smile.txt
# writing Yung Joc_We bottle poppin.txt
# writing Yung Joc_It’s Going Down Remix.txt
# writing Yung Joc_Excuse Me Officer (Interlude).txt
# writing Yung Joc_500 Horses.txt
# writing Yung Joc_Pak Man.txt
# writing Yung Joc_Mollie.txt
# Top 50 songs by Yung Joc downloaded.
